# %% [markdown]
# # Utiliser l'API Google Books pour récupérer des données de livres
#
# ## Partie 1 : Comprendre les API

# %% [markdown]
# ### a. Qu’est-ce qu’une API ?
# - API = Application Programming Interface
# - Une API est une interface qui permet à un programme d’accéder aux fonctionnalités ou aux données d’un autre service, sans avoir besoin de connaître son fonctionnement interne.
# - Exemple : l’API Google Books met à disposition des données sur des millions de livres, que l’on peut interroger depuis un programme Python.
# - On envoie une **requête** (question) à l’API, elle nous répond avec des **données** (souvent en JSON)

# %% [markdown]
# ### b. Qu’est-ce qu’une requête HTTP ?
# - HTTP = HyperText Transfer Protocol – c’est le protocole qui permet à des machines (navigateur, script Python, application mobile...) de communiquer avec des serveurs sur Internet.
# - Une requête HTTP est un message envoyé depuis un client (comme un navigateur ou un programme Python) vers un serveur web pour lui demander quelque chose.
# - Quand on ouvre un site web ou que l'on demande des données à une API, on envoie une **requête HTTP**, généralement de type :
#
#     - **GET** → pour demander des données
#     - **POST** → pour envoyer des données
#     - **PUT**, **DELETE**, etc.
#
# - L’API Google Books utilise principalement des requêtes de type GET, comme si on entrait une URL dans un navigateur pour demander des infos.
# - Une URL de requête API suit une structure bien définie :
#
# `<URL de base> ? <paramètre1>=<valeur1> & <paramètre2>=<valeur2> & ...`
#
# - URL de base : adresse du point d’entrée de l’API, aussi appelée **endpoint**.
# - ? : sépare l’URL de base des paramètres de requête.
# - Paramètres de requête (query parameters) : ajoutés sous forme de paires clé=valeur. Chaque paramètre est séparé par &.  Les paramètres possibles sont disponibles dans la documentation de chaque API.

# %% [markdown]
# ### c. Réponse
#
# Quand on envoie une requête GET à une API, on demande au serveur de renvoyer une ressource.
#
# La réponse de ce serveur comporte deux parties essentielles :

# %% [markdown]
# 1. **Le code de status de réponse (HTTP status code)**
#
# C’est un nombre à 3 chiffres qui indique si la requête a réussi ou non.
#
# --> [Liste des codes possibles](https://developer.mozilla.org/fr/docs/Web/HTTP/Reference/Status) et leur signification

# %% [markdown]
# 2. **Le contenu de la réponse (le "corps")**
#
# C’est ici que se trouvent les données demandées.
#
# Ce contenu est souvent au format JSON (JavaScript Object Notation), c’est-à-dire une structure clé-valeur que Python peut facilement lire.
#
# Exemple d'un format JSON :
# ```json
# {
#   "items": [
#     {
#       "tripInfo": {
#         "country": "France",
#         "cities": ["Montpellier", "Marseille"],
#         "nb_photo_taken": 200,
#         "language": "fr"
#       }
#     }
#   ]
# }
# ```

# %% [markdown]
# ---
# ## Partie 2 : Requêter Google Books API
#
# Dans cette partie vous allez :
# - Faire une requête HTTP pour interroger l'API Google Books à l'aide de la bibliothèque python _requests_,
# - Vérifier le code de status de la réponse,
# - Traiter le corps de la réponse à l'aide de la bibliothèque python _json_,
# - Utiliser _pandas_ pour convertir les données reçues en dataframe.

# %%
# Importer les bibliothèques nécessaires
import requests
import json
import pandas as pd

# %% [markdown]
# Pour interroger une API, un certain nombre de paramètres et filtres définis dans la documentation peuvent être utilisés.
#
# En utilisant la [documentation](https://developers.google.com/books/docs/v1/using?hl=fr#WorkingVolumes) de l'API Google Books, définir le dictionnaire de paramètres permettant de faire une recherche sur :
# - la chaîne de texte : "food",
# - il doit s'agir d'un e-book avec un prix d'achat,
# - le nombre maximal de résultats à renvoyer est de 40,
# - les résultats doivent être triés par pertinence.

# %%
# URL de l'API Google Books
url = "https://www.googleapis.com/books/v1/volumes"

# Dictionnaire de paramètres pour la requête 
params = {"q": "food",
          "filter": "paid-ebooks",
          "maxResults": 40,
          "orderBy": "relevance"
          }

#url = "https://www.googleapis.com/books/v1/volumes?q=food&filter=paid-ebooks&maxResults=40&orderBy:relevance"

# %% [markdown]
# En utilisant la documentation de la bibliothèque [_requests_](https://requests.readthedocs.io/en/latest/user/quickstart/):
# - implémenter la requête HTTP _get_  avec les paramètres sur l'URL définie ci-dessus,
# - vérifier le code de réponse HTTP.

# %%
# Requêter l'API Google Books
response = requests.get(url, params=params)

# Vérifier le code de statut de la réponse
print(response.status_code)

#Ici on envoie une requête HTTP GET vers l’API Google Books
#La bibliothèque requests va construire automatiquement l’URL complète : "https://www.googleapis.com/books/v1/volumes?q=food&filter=paid-ebooks&maxResults=40&orderBy:relevance"
#Puis elle envoie la requête au serveur Google.
#Le résultat est stocké dans l’objet response.
# Out:
# 200

# %% [markdown]
# Récupérer et observer le coeur de la réponse via l'objet _response_ créé précédemment.

# %%
from pprint import pprint

# Récupérer le coeur de la réponse
data_books_raw = response.json()

# Afficher les données récupérées
pprint(data_books_raw)

# Afficher le type de la variable data_books_raw
print(type(data_books_raw)) # ---> <class 'dict'>

#La méthode .json() de l’objet response :
#lit le corps de la réponse HTTP (qui est en format JSON, c’est-à-dire du texte structuré)
#et le convertit en dictionnaire Python (dict) automatiquement.
#exemple:
{
  "kind": "books#volumes",
  "totalItems": 123,
  "items": [ {...} ]
}

#print(data_books_raw.keys())
#print(json.dumps(data_books_raw, indent=2))

#Donc en résumé :
#response.json() → convertit le JSON en dict Python
#print(...) → affiche les données
#type(...) → confirme la structure (dict)
# Out:
# {'items': [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Encyclopedia_of_Food_and_Health-sample-pdf.acsm?id=O-t9BAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=O-t9BAAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': '5IbTl5Yjx6Q',
#             'id': 'O-t9BAAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&rdid=book-O-t9BAAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 3334, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 3334000000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 3334000000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 3334, 'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>food</b>. Importance. of. '
#                                           '<b>Food</b>. Classification. and. '
#                                           'Description. The preparation of '
#                                           'reliable data on <b>food</b> '
#                                           'requires precise iden- tification '
#                                           'of <b>foods</b>. Even data of good '
#                                           'quality can be a source of error if '
#                                           'they are derived from <b>foods</b> '
#                                           'that are&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/O-t9BAAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ',
#                            'categories': ['Technology & Engineering'],
#                            'contentVersion': '2.6.5.0.preview.1',
#                            'description': 'Approx.3876 pages Approx.3876 pages',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9780123849533',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '0123849535',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 2379,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=O-t9BAAAQBAJ&pg=RA2-PA1&dq=food&hl=&as_brr=6&cd=1&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2015-08-26',
#                            'publisher': 'Academic Press',
#                            'readingModes': {'image': True, 'text': False},
#                            'title': 'Encyclopedia of Food and Health'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'acsTokenLink': 'http://books.google.fr/books/download/Advances_in_Deep_Fat_Frying_of_Foods-sample-epub.acsm?id=RgU9u9oUSDQC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                     'isAvailable': True},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Advances_in_Deep_Fat_Frying_of_Foods-sample-pdf.acsm?id=RgU9u9oUSDQC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=RgU9u9oUSDQC&hl=&as_brr=6&source=gbs_api'},
#             'etag': 'HRBdurYHmRs',
#             'id': 'RgU9u9oUSDQC',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=RgU9u9oUSDQC&rdid=book-RgU9u9oUSDQC&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 274.3, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 274300000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 216280000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 216.28,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>Food</b> Engineering 29 ( 2 '
#                                           ') : 167–83 . Karathanos , V.T. , '
#                                           'and G.D. Saravacos . 1993. Porosity '
#                                           'and pore size distribution of '
#                                           'starch materials . Journal of '
#                                           '<b>Food</b> Engineering 18 ( 3 ) : '
#                                           '259–80 . Kassama , L.S. 2003. Pore '
#                                           'development in '
#                                           '<b>food</b>&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/RgU9u9oUSDQC',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Servet Gulum Sumnu', 'Serpil Sahin'],
#                            'averageRating': 5,
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=RgU9u9oUSDQC',
#                            'categories': ['Technology & Engineering'],
#                            'contentVersion': '1.3.6.0.preview.3',
#                            'description': 'Battered fried foods consistently '
#                                           'remain in high demand despite '
#                                           'concerns about their health '
#                                           'aspects, prompting food processors '
#                                           'to develop new methods and '
#                                           'alternative oils and batters in the '
#                                           'name of healthy, tasty fried foods '
#                                           'and high-performance, '
#                                           'cost-effective frying oil. With '
#                                           'contributions from an international '
#                                           'panel of food technology authoritie',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=RgU9u9oUSDQC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=RgU9u9oUSDQC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781420055597',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1420055593',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=RgU9u9oUSDQC&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 330,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=RgU9u9oUSDQC&pg=PA197&dq=food&hl=&as_brr=6&cd=2&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2008-12-17',
#                            'publisher': 'CRC Press',
#                            'ratingsCount': 1,
#                            'readingModes': {'image': True, 'text': True},
#                            'title': 'Advances in Deep-Fat Frying of Foods'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Solid_State_Fermentation_for_Foods_and_B-sample-pdf.acsm?id=CSHOBQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=CSHOBQAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': '5gGWzlPZxKM',
#             'id': 'CSHOBQAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=CSHOBQAAQBAJ&rdid=book-CSHOBQAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 90.72, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 90720000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 69410000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 69.41,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>food</b> shortage problem. '
#                                           'With the adaptation of <b>food</b> '
#                                           'fermentation, the indigenous self- '
#                                           'help famine relief has been '
#                                           'successfully achieved. Most '
#                                           'fermented <b>foods</b> appear to '
#                                           'have been developed to ensure the '
#                                           'nutrition of the family in the '
#                                           'dry&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/CSHOBQAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Jian Chen', 'Yang Zhu'],
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=CSHOBQAAQBAJ',
#                            'categories': ['Science'],
#                            'contentVersion': '1.4.4.0.preview.1',
#                            'description': 'Although one of the oldest '
#                                           'microbial technologies used in food '
#                                           'processing, solid-state '
#                                           'fermentation (SSF) had, until '
#                                           'recently, fallen out of favor. '
#                                           'However, based on a series of '
#                                           'established mathematical models, '
#                                           'new design concepts for SSF '
#                                           'bioreactors and process control '
#                                           'strategies have been proposed, '
#                                           'allowing SSF technology to reach '
#                                           'new levels. Sol',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=CSHOBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=CSHOBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781439844977',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1439844976',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=CSHOBQAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 404,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=CSHOBQAAQBAJ&pg=PA350&dq=food&hl=&as_brr=6&cd=3&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2013-11-23',
#                            'publisher': 'CRC Press',
#                            'readingModes': {'image': True, 'text': False},
#                            'title': 'Solid State Fermentation for Foods and '
#                                     'Beverages'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'acsTokenLink': 'http://books.google.fr/books/download/In_Pack_Processed_Foods-sample-epub.acsm?id=uvaiAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                     'isAvailable': True},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/In_Pack_Processed_Foods-sample-pdf.acsm?id=uvaiAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=uvaiAgAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': 'XI+miohslf4',
#             'id': 'uvaiAgAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=uvaiAgAAQBAJ&rdid=book-uvaiAgAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 226.82, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 226820000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 158770000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 158.77,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>Food</b> Science, 45(6), pp. '
#                                           '1517–1521. Parry, D. A. 1970, Fish '
#                                           'as <b>food</b>, in Proteins as '
#                                           'Human <b>Foods</b>, R. A. Lawrie, '
#                                           'ed., Butterworths, London, p. 365. '
#                                           'Pedrosa-Menabrito, A. and '
#                                           'Regenstein, J. M. 1990, Shelf-life '
#                                           'Extension of Fresh Fish&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/uvaiAgAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['P Richardson'],
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=uvaiAgAAQBAJ',
#                            'categories': ['Technology & Engineering'],
#                            'contentVersion': '0.4.3.0.preview.3',
#                            'description': 'Recent developments have enabled '
#                                           'the production of in-pack processed '
#                                           'foods with improved sensory quality '
#                                           'as well as new types of '
#                                           'heat-preserved products packaged in '
#                                           'innovative containers. This book '
#                                           'reviews these advances in packaging '
#                                           'formats and processing technologies '
#                                           'and their application to produce '
#                                           'higher quality, safer foods.Opening '
#                                           'chapters cover innovative can '
#                                           'designs and non-traditional '
#                                           'packaging formats, such as retort '
#                                           'pouches. The second part of the '
#                                           'book reviews the developments in '
#                                           'processing and process control '
#                                           'technology required by newer types '
#                                           'of packaging. Part three addresses '
#                                           'the safety of in-pack processed '
#                                           'foods, including concerns over '
#                                           'pathogens and hazardous compounds '
#                                           'in processed foods. The book '
#                                           'concludes with chapters on novel '
#                                           'methods to optimise the quality of '
#                                           'particular types of in-pack '
#                                           'processed foods such as fruit and '
#                                           'vegetables, meat, poultry and fish '
#                                           'products.In-pack processed foods: '
#                                           'improving quality is a valuable '
#                                           'reference for professionals '
#                                           'involved in the manufacture of this '
#                                           'important group of food products '
#                                           'and those researching in this area. '
#                                           '- Reviews advances in packaging '
#                                           'formats and processing technologies '
#                                           '- Covers innovative can designs and '
#                                           'non-traditional packaging formats - '
#                                           'Examines the safety of in-pack '
#                                           'processed foods, including concerns '
#                                           'over pathogens',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=uvaiAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=uvaiAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781845694692',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1845694694',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=uvaiAgAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 428,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=uvaiAgAAQBAJ&pg=PA401&dq=food&hl=&as_brr=6&cd=4&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2008-06-13',
#                            'publisher': 'Elsevier',
#                            'readingModes': {'image': True, 'text': True},
#                            'subtitle': 'Improving Quality',
#                            'title': 'In-Pack Processed Foods'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'acsTokenLink': 'http://books.google.fr/books/download/Current_Advances_for_Development_of_Func-sample-epub.acsm?id=NmI7EAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                     'isAvailable': True},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Current_Advances_for_Development_of_Func-sample-pdf.acsm?id=NmI7EAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=NmI7EAAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': 'os/o1FCK9lc',
#             'id': 'NmI7EAAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=NmI7EAAAQBAJ&rdid=book-NmI7EAAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 184.62, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 184620000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 129230000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 129.23,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>foods</b>. Application of '
#                                           'multiple emulsions to formulate the '
#                                           'functional <b>food</b> products '
#                                           'have been recognized for several '
#                                           'years such as the development of '
#                                           'low-fat imitation creams, fat '
#                                           'reduced mayonnaise (Moussaoui et '
#                                           'al., 2017), low-fat&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/NmI7EAAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Blanca Hernandez-Ledesma',
#                                        'Cristina Martinez-Villaluenga'],
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=NmI7EAAAQBAJ',
#                            'categories': ['Technology & Engineering'],
#                            'contentVersion': '1.5.5.0.preview.3',
#                            'description': 'Current Advances for Development of '
#                                           'Functional Foods Modulating '
#                                           'Inflammation and Oxidative Stress '
#                                           'presents the nutritional and '
#                                           'technological aspects related to '
#                                           'the development of functional foods '
#                                           'with anti-inflammatory and '
#                                           'antioxidant effects. Specifically, '
#                                           'analytical approaches for the '
#                                           'characterization of '
#                                           'anti-inflammatory and antioxidant '
#                                           'properties of healthy foods and '
#                                           'functional constituents, as well as '
#                                           'technological strategies for the '
#                                           'extraction of compounds and '
#                                           'fractions from raw materials to '
#                                           'produce anti-inflammatory and '
#                                           'antioxidant ingredients are '
#                                           'addressed. In addition, the '
#                                           'molecular mechanisms by which foods '
#                                           'and their components can modulate '
#                                           'inflammation and their oxidative '
#                                           'stress effects on disease '
#                                           'prevention are explored. Finally, '
#                                           'clinical research addressing '
#                                           'nutritional needs in pathological '
#                                           'subjects with inflammatory diseases '
#                                           'are considered. - Covers methods of '
#                                           'analysis and extraction of '
#                                           'anti-inflammatory and antioxidant '
#                                           'compounds - Offers an overview of '
#                                           'the main anti-inflammatory and '
#                                           'antioxidant compounds in foods - '
#                                           'Provides a guide on the mechanisms '
#                                           'of action and health benefits of '
#                                           'anti-inflammatory and antioxidant '
#                                           'dietary bioactives',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=NmI7EAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=NmI7EAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9780128225844',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '012822584X',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=NmI7EAAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 676,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=NmI7EAAAQBAJ&pg=PA81&dq=food&hl=&as_brr=6&cd=5&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2021-12-03',
#                            'publisher': 'Academic Press',
#                            'readingModes': {'image': True, 'text': True},
#                            'title': 'Current Advances for Development of '
#                                     'Functional Foods Modulating Inflammation '
#                                     'and Oxidative Stress'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Fermented_Foods_and_Beverages_of_the_Wor-sample-pdf.acsm?id=MJTLBQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=MJTLBQAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': '3ZdYHXAo8fA',
#             'id': 'MJTLBQAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=MJTLBQAAQBAJ&rdid=book-MJTLBQAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 211, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 211000000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 165640000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 165.64,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>Food</b> Composition and '
#                                           'Analysis 20 : 113–118 . Silla '
#                                           'Santos , M.H. 1996. Biogenic amines '
#                                           ': Their importance in <b>foods</b> '
#                                           '. International Journal of '
#                                           '<b>Food</b> Microbiology 29 : '
#                                           '213–231 . Silva , C.F. , L.R. '
#                                           'Batista , L.M. Abreu , E.S. Dias , '
#                                           'and&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/MJTLBQAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Jyoti Prakash Tamang',
#                                        'Kasipathy Kailasapathy'],
#                            'averageRating': 5,
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=MJTLBQAAQBAJ',
#                            'categories': ['Technology & Engineering'],
#                            'contentVersion': '0.3.3.0.preview.1',
#                            'description': "Did you know? It's estimated that "
#                                           'fermentation practices have been '
#                                           'around since as early as 6000 BC, '
#                                           'when wine was first being made in '
#                                           'Caucasus and Mesopotamia. Today, '
#                                           'there are roughly 5000 varieties of '
#                                           'fermented foods and beverages '
#                                           'prepared and consumed worldwide, '
#                                           'which accounts for between five and '
#                                           'forty percent of daily meals. '
#                                           'Fermented Foods a',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=MJTLBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=MJTLBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781420094961',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1420094963',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=MJTLBQAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 462,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=MJTLBQAAQBAJ&pg=PA81&dq=food&hl=&as_brr=6&cd=6&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2010-07-01',
#                            'publisher': 'CRC Press',
#                            'ratingsCount': 1,
#                            'readingModes': {'image': True, 'text': False},
#                            'title': 'Fermented Foods and Beverages of the '
#                                     'World'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'acsTokenLink': 'http://books.google.fr/books/download/Biopolymers_in_Nutraceuticals_and_Functi-sample-epub.acsm?id=mRebEAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                     'isAvailable': True},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Biopolymers_in_Nutraceuticals_and_Functi-sample-pdf.acsm?id=mRebEAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=mRebEAAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': 'SiKH/g/79hI',
#             'id': 'mRebEAAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=mRebEAAAQBAJ&rdid=book-mRebEAAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 236.32, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 236320000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 165420000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 165.42,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>Food</b> and Health, ed. B. '
#                                           'Caballero, P. Finglas and F. '
#                                           'Toldrá, Elsevier Inc., Amsterdam, '
#                                           '1st edn, 2015, pp. 294–300. 11. D. '
#                                           'Mudgil, S. Barak and B. S. Khatkar, '
#                                           'Guar Gum: processing, properties '
#                                           'and <b>food</b> applications - A '
#                                           'Review, J. <b>Food</b> '
#                                           'Sci&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/mRebEAAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Sreerag Gopi',
#                                        'Preetha Balakrishnan',
#                                        'Matej Bračič'],
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=mRebEAAAQBAJ',
#                            'categories': ['Technology & Engineering'],
#                            'contentVersion': '1.2.3.0.preview.3',
#                            'description': 'As a result of their unique '
#                                           'physical properties, biological '
#                                           'membrane mimetics such as '
#                                           'biopolymers are used in a broad '
#                                           'range of scientific and '
#                                           'technological applications. This '
#                                           'comprehensive book covers new '
#                                           'applications of biopolymers in the '
#                                           'research and development of '
#                                           'industrial scale nutraceutical and '
#                                           'functional food grade products. All '
#                                           'the major food biopolymers are '
#                                           'included, from plant, animal and '
#                                           'marine sources. Coverage also '
#                                           'includes biopolymer-based drug '
#                                           'delivery mechanisms intended for '
#                                           'biological applications such as '
#                                           'bio-detection of pathogens, '
#                                           'fluorescent biological labels, and '
#                                           'drug and gene delivery. This is the '
#                                           'first interdisciplinary book to '
#                                           'address this area specifically and '
#                                           'is essential reading for those who '
#                                           'produce the functional biopolymer '
#                                           'materials as well as those who seek '
#                                           'to incorporate them into '
#                                           'appropriate nutraceutical, food and '
#                                           'drug delivery products.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=mRebEAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=mRebEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781839168055',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1839168056',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=mRebEAAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 495,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=mRebEAAAQBAJ&pg=PT334&dq=food&hl=&as_brr=6&cd=7&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2022-11-04',
#                            'publisher': 'Royal Society of Chemistry',
#                            'readingModes': {'image': True, 'text': True},
#                            'title': 'Biopolymers in Nutraceuticals and '
#                                     'Functional Foods'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'isAvailable': False},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Fermentation_Biotechnology_for_Functiona-sample-pdf.acsm?id=6iyIEQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=6iyIEQAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': 'k4r8Fknep1U',
#             'id': '6iyIEQAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=6iyIEQAAQBAJ&rdid=book-6iyIEQAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 247.92, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 247920000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 195180000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 195.18,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>Food</b> Sciences and '
#                                           'Nutrition 61, no. 2: 125–137. '
#                                           'Hassan, Z. 1980. Pekasam—A '
#                                           'fermented fish product (in '
#                                           'Peninsular Malaysia). In Seminar on '
#                                           'Modernization of Malaysian Cottage '
#                                           '<b>Food</b> Industries. Serdang: '
#                                           'Universiti Pertanian Malaysia. '
#                                           'Ho&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/6iyIEQAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['Kalidas Shetty', 'Lena Gálvez Ranilla'],
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=6iyIEQAAQBAJ',
#                            'categories': ['Technology & Engineering'],
#                            'contentVersion': 'preview-1.0.0',
#                            'description': 'Fermentation-based processing '
#                                           'advanced with global food systems '
#                                           'as humanity started to organize the '
#                                           'domestication of agriculture from '
#                                           'plant and animal sources. These '
#                                           'advances emerged across regions of '
#                                           'the world from river valley '
#                                           'civilizations in Asia (Mesopotamia, '
#                                           'India and China) and Africa (Egypt) '
#                                           'to Meso-American civilizations. As '
#                                           'food crops and animal foods emerged '
#                                           'from domestication to advancements '
# ...
#                                           'their own food supplies are ample, '
#                                           'they even help out other bears in '
#                                           'need. Could these cooperative '
#                                           'behaviors, he asks, mimic behavior '
#                                           'that existed in the animal that '
#                                           'became human? In watching bears, do '
#                                           'we see our earliest forms of '
#                                           'communications unfold? Kilham’s '
#                                           'dyslexia once barred him from '
#                                           'getting an advanced academic '
#                                           'degree, securing funding for his '
#                                           'research, and publishing his '
#                                           'observations in the scientific '
#                                           'literature. After being shunned by '
#                                           'the traditional scientific '
#                                           'community, though, Kilham’s unique '
#                                           'findings now interest bear '
#                                           'researchers worldwide. His '
#                                           'techniques even aid scientists '
#                                           'working with pandas in China and '
#                                           'bears in Russia. Moreover, the '
#                                           'observation skills that fueled '
#                                           'Kilham’s exceptional work turned '
#                                           'out to be born of his dyslexia. His '
#                                           'ability to think in pictures and '
#                                           'decipher systems makes him a unique '
#                                           'interpreter of the bear’s world. In '
#                                           'the Company of Bears delivers '
#                                           'Kilham’s fascinating glimpse at the '
#                                           'inner world of bears, and also '
#                                           'makes a passionate case for '
#                                           'science, and education in general, '
#                                           'to open its doors to different ways '
#                                           'of learning and researching–doors '
#                                           'that could lead to far broader '
#                                           'realms of discovery.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=ck9HBAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=ck9HBAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781603586009',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1603586008',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=ck9HBAAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 201,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=ck9HBAAAQBAJ&pg=PT186&dq=food&hl=&as_brr=6&cd=38&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2014-09-01',
#                            'publisher': 'Chelsea Green Publishing',
#                            'readingModes': {'image': True, 'text': True},
#                            'subtitle': 'What Black Bears Have Taught Me about '
#                                        'Intelligence and Intuition',
#                            'title': 'In the Company of Bears'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'acsTokenLink': 'http://books.google.fr/books/download/Advertising_to_Children-sample-epub.acsm?id=nx1vBAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                     'isAvailable': True},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Advertising_to_Children-sample-pdf.acsm?id=nx1vBAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=nx1vBAAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': 'O+lTvV2ej8Y',
#             'id': 'nx1vBAAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=nx1vBAAAQBAJ&rdid=book-nx1vBAAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 94.94, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 94940000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 63290000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 63.29,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>food</b> adverts and brand '
#                                           'recognition Effects on <b>food</b> '
#                                           'preferences and choice Borzekowski '
#                                           'and Robinson (2001) carried out a '
#                                           'randomized, controlled trial in '
#                                           'which they showed preschool '
#                                           'children a videotape of a cartoon '
#                                           'either with or without&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/nx1vBAAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['M. Blades',
#                                        'C. Oates',
#                                        'F. Blumberg',
#                                        'B. Gunter'],
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=nx1vBAAAQBAJ',
#                            'categories': ['Psychology'],
#                            'contentVersion': '1.7.5.0.preview.3',
#                            'description': 'This important source for students, '
#                                           'researchers, advertisers and '
#                                           'parents reviews the debates and '
#                                           'presents new research about '
#                                           'advertising to children. Chapters '
#                                           'cover food and alcohol advertising, '
#                                           'the effects of product placement '
#                                           'and new media advertising, and the '
#                                           'role of parents and teachers in '
#                                           'helping children to learn more '
#                                           'about advertising.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=nx1vBAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=nx1vBAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781137313256',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1137313250',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=nx1vBAAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 264,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=nx1vBAAAQBAJ&pg=PA57&dq=food&hl=&as_brr=6&cd=39&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2014-08-29',
#                            'publisher': 'Springer',
#                            'readingModes': {'image': True, 'text': True},
#                            'subtitle': 'New Directions, New Media',
#                            'title': 'Advertising to Children'}},
#            {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                            'country': 'FR',
#                            'embeddable': True,
#                            'epub': {'acsTokenLink': 'http://books.google.fr/books/download/Environmentalism_Resistance_and_Solidari-sample-epub.acsm?id=wBmuAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                     'isAvailable': True},
#                            'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Environmentalism_Resistance_and_Solidari-sample-pdf.acsm?id=wBmuAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                                    'isAvailable': True},
#                            'publicDomain': False,
#                            'quoteSharingAllowed': False,
#                            'textToSpeechPermission': 'ALLOWED',
#                            'viewability': 'PARTIAL',
#                            'webReaderLink': 'http://play.google.com/books/reader?id=wBmuAgAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#             'etag': 'v8Sut3+Oa7M',
#             'id': 'wBmuAgAAQBAJ',
#             'kind': 'books#volume',
#             'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=wBmuAgAAQBAJ&rdid=book-wBmuAgAAQBAJ&rdot=1&source=gbs_api',
#                          'country': 'FR',
#                          'isEbook': True,
#                          'listPrice': {'amount': 52.74, 'currencyCode': 'EUR'},
#                          'offers': [{'finskyOfferType': 1,
#                                      'giftable': True,
#                                      'listPrice': {'amountInMicros': 52740000,
#                                                    'currencyCode': 'EUR'},
#                                      'retailPrice': {'amountInMicros': 34280000,
#                                                      'currencyCode': 'EUR'}}],
#                          'retailPrice': {'amount': 34.28,
#                                          'currencyCode': 'EUR'},
#                          'saleability': 'FOR_SALE'},
#             'searchInfo': {'textSnippet': '... <b>food</b> system and &#39;the '
#                                           'need to refocus attention on the '
#                                           'billion and a half men and women '
#                                           'who produce the <b>food</b> we all '
#                                           'eat&#39;.3 FoEI was one of the '
#                                           'forum&#39;s organizers, with '
#                                           'REDES/FoE Uruguay&#39;s Martín '
#                                           'Drago sitting on the '
#                                           'International&nbsp;...'},
#             'selfLink': 'https://www.googleapis.com/books/v1/volumes/wBmuAgAAQBAJ',
#             'volumeInfo': {'allowAnonLogging': False,
#                            'authors': ['B. Doherty', 'T. Doyle'],
#                            'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=wBmuAgAAQBAJ',
#                            'categories': ['Political Science'],
#                            'contentVersion': '1.4.4.0.preview.3',
#                            'description': 'Drawing from a rich mix of survey '
#                                           'data, interviews, and access to '
#                                           'internal meetings, Brian Doherty '
#                                           'and Timothy Doyle show how FoEI has '
#                                           'developed a distinctive '
#                                           'environmentalism, which allows for '
#                                           'the differences in context between '
#                                           'regions and across the North-South '
#                                           'divide.',
#                            'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=wBmuAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                           'thumbnail': 'http://books.google.com/books/content?id=wBmuAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                            'industryIdentifiers': [{'identifier': '9781137316714',
#                                                     'type': 'ISBN_13'},
#                                                    {'identifier': '1137316713',
#                                                     'type': 'ISBN_10'}],
#                            'infoLink': 'https://play.google.com/store/books/details?id=wBmuAgAAQBAJ&source=gbs_api',
#                            'language': 'en',
#                            'maturityRating': 'NOT_MATURE',
#                            'pageCount': 260,
#                            'panelizationSummary': {'containsEpubBubbles': False,
#                                                    'containsImageBubbles': False},
#                            'previewLink': 'http://books.google.fr/books?id=wBmuAgAAQBAJ&pg=PA157&dq=food&hl=&as_brr=6&cd=40&source=gbs_api',
#                            'printType': 'BOOK',
#                            'publishedDate': '2013-10-16',
#                            'publisher': 'Springer',
#                            'readingModes': {'image': True, 'text': True},
#                            'subtitle': 'The Politics of Friends of the Earth '
#                                        'International',
#                            'title': 'Environmentalism, Resistance and '
#                                     'Solidarity'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1000000}
# <class 'dict'>
# {'kind': 'books#volumes', 'totalItems': 123, 'items': [{Ellipsis}]}

# %% [markdown]
# - Les données relatives aux livres récupérées sont accessibles dans la clé 'items',
# - Récupérer les données relatives aux livres dans la variable data_books.
#
# **NOTE**
#
# Il existe 2 méthodes pour accéder aux valeurs d'une clé ("nom_de_la_clé") d'un dictionnaire python :
# - `mon_dict["nom_de_la_clé"]`: si "nom_de_la_clé" n'est pas présent dans le dictionnaire, cela retourne une erreur.
# - `mon_dict.get("nom_de_la_clé")` : si "nom_de_la_clé" n'est pas présent dans le dictionnaire, cela renvoie None par défault.
# Il est aussi possible d'indiquer comme second argument la variable à renvoyer si la clé n'est pas présente :
#
# `mon_dict.get("nom_de_la_clé", "clé inexistante")`
#
# Privilégier la seconde méthode car certaines clés peuvent ne pas exister.
#
# --> [Lien ressource](https://w3schools.tech/fr/tutorial/python/python_access_dictionary_items) : accès au clé/valeurs d'un dictionnaire python

# %%
# Récupérer les données relatives aux livres via la clé 'items'
data_books = data_books_raw["items"] #data_books.get("items", "items is not an existing clé name")

# Afficher le type de la variable data_books
print(type(data_books)) #---> this is a list!

#print(json.dumps(data_books, indent=2))
pprint(data_books[0])
# Out:
# <class 'list'>
# {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                 'country': 'FR',
#                 'embeddable': True,
#                 'epub': {'isAvailable': False},
#                 'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Encyclopedia_of_Food_and_Health-sample-pdf.acsm?id=O-t9BAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                         'isAvailable': True},
#                 'publicDomain': False,
#                 'quoteSharingAllowed': False,
#                 'textToSpeechPermission': 'ALLOWED',
#                 'viewability': 'PARTIAL',
#                 'webReaderLink': 'http://play.google.com/books/reader?id=O-t9BAAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#  'etag': '5IbTl5Yjx6Q',
#  'id': 'O-t9BAAAQBAJ',
#  'kind': 'books#volume',
#  'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&rdid=book-O-t9BAAAQBAJ&rdot=1&source=gbs_api',
#               'country': 'FR',
#               'isEbook': True,
#               'listPrice': {'amount': 3334, 'currencyCode': 'EUR'},
#               'offers': [{'finskyOfferType': 1,
#                           'giftable': True,
#                           'listPrice': {'amountInMicros': 3334000000,
#                                         'currencyCode': 'EUR'},
#                           'retailPrice': {'amountInMicros': 3334000000,
#                                           'currencyCode': 'EUR'}}],
#               'retailPrice': {'amount': 3334, 'currencyCode': 'EUR'},
#               'saleability': 'FOR_SALE'},
#  'searchInfo': {'textSnippet': '... <b>food</b>. Importance. of. <b>Food</b>. '
#                                'Classification. and. Description. The '
#                                'preparation of reliable data on <b>food</b> '
#                                'requires precise iden- tification of '
#                                '<b>foods</b>. Even data of good quality can be '
#                                'a source of error if they are derived from '
#                                '<b>foods</b> that are&nbsp;...'},
#  'selfLink': 'https://www.googleapis.com/books/v1/volumes/O-t9BAAAQBAJ',
#  'volumeInfo': {'allowAnonLogging': False,
#                 'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ',
#                 'categories': ['Technology & Engineering'],
#                 'contentVersion': '2.6.5.0.preview.1',
#                 'description': 'Approx.3876 pages Approx.3876 pages',
#                 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                'thumbnail': 'http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                 'industryIdentifiers': [{'identifier': '9780123849533',
#                                          'type': 'ISBN_13'},
#                                         {'identifier': '0123849535',
#                                          'type': 'ISBN_10'}],
#                 'infoLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&source=gbs_api',
#                 'language': 'en',
#                 'maturityRating': 'NOT_MATURE',
#                 'pageCount': 2379,
#                 'panelizationSummary': {'containsEpubBubbles': False,
#                                         'containsImageBubbles': False},
#                 'previewLink': 'http://books.google.fr/books?id=O-t9BAAAQBAJ&pg=RA2-PA1&dq=food&hl=&as_brr=6&cd=1&source=gbs_api',
#                 'printType': 'BOOK',
#                 'publishedDate': '2015-08-26',
#                 'publisher': 'Academic Press',
#                 'readingModes': {'image': True, 'text': False},
#                 'title': 'Encyclopedia of Food and Health'}}

# %% [markdown]
# Accéder au premier élément de _data_books_ pour afficher les données du premier livre.
#
# --> [Lien ressource](https://w3schools.tech/fr/tutorial/python/python_access_list_items) : accéder aux éléments d'une liste python

# %%
# Afficher le premier livre
pprint(data_books[0])
# Out:
# {'accessInfo': {'accessViewStatus': 'SAMPLE',
#                 'country': 'FR',
#                 'embeddable': True,
#                 'epub': {'isAvailable': False},
#                 'pdf': {'acsTokenLink': 'http://books.google.fr/books/download/Encyclopedia_of_Food_and_Health-sample-pdf.acsm?id=O-t9BAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#                         'isAvailable': True},
#                 'publicDomain': False,
#                 'quoteSharingAllowed': False,
#                 'textToSpeechPermission': 'ALLOWED',
#                 'viewability': 'PARTIAL',
#                 'webReaderLink': 'http://play.google.com/books/reader?id=O-t9BAAAQBAJ&hl=&as_brr=6&source=gbs_api'},
#  'etag': '5IbTl5Yjx6Q',
#  'id': 'O-t9BAAAQBAJ',
#  'kind': 'books#volume',
#  'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&rdid=book-O-t9BAAAQBAJ&rdot=1&source=gbs_api',
#               'country': 'FR',
#               'isEbook': True,
#               'listPrice': {'amount': 3334, 'currencyCode': 'EUR'},
#               'offers': [{'finskyOfferType': 1,
#                           'giftable': True,
#                           'listPrice': {'amountInMicros': 3334000000,
#                                         'currencyCode': 'EUR'},
#                           'retailPrice': {'amountInMicros': 3334000000,
#                                           'currencyCode': 'EUR'}}],
#               'retailPrice': {'amount': 3334, 'currencyCode': 'EUR'},
#               'saleability': 'FOR_SALE'},
#  'searchInfo': {'textSnippet': '... <b>food</b>. Importance. of. <b>Food</b>. '
#                                'Classification. and. Description. The '
#                                'preparation of reliable data on <b>food</b> '
#                                'requires precise iden- tification of '
#                                '<b>foods</b>. Even data of good quality can be '
#                                'a source of error if they are derived from '
#                                '<b>foods</b> that are&nbsp;...'},
#  'selfLink': 'https://www.googleapis.com/books/v1/volumes/O-t9BAAAQBAJ',
#  'volumeInfo': {'allowAnonLogging': False,
#                 'canonicalVolumeLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ',
#                 'categories': ['Technology & Engineering'],
#                 'contentVersion': '2.6.5.0.preview.1',
#                 'description': 'Approx.3876 pages Approx.3876 pages',
#                 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#                                'thumbnail': 'http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#                 'industryIdentifiers': [{'identifier': '9780123849533',
#                                          'type': 'ISBN_13'},
#                                         {'identifier': '0123849535',
#                                          'type': 'ISBN_10'}],
#                 'infoLink': 'https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&source=gbs_api',
#                 'language': 'en',
#                 'maturityRating': 'NOT_MATURE',
#                 'pageCount': 2379,
#                 'panelizationSummary': {'containsEpubBubbles': False,
#                                         'containsImageBubbles': False},
#                 'previewLink': 'http://books.google.fr/books?id=O-t9BAAAQBAJ&pg=RA2-PA1&dq=food&hl=&as_brr=6&cd=1&source=gbs_api',
#                 'printType': 'BOOK',
#                 'publishedDate': '2015-08-26',
#                 'publisher': 'Academic Press',
#                 'readingModes': {'image': True, 'text': False},
#                 'title': 'Encyclopedia of Food and Health'}}

# %%
with open("show_books.json", "w", encoding="utf-8") as f:
    json.dump(data_books_raw, f, indent=2, ensure_ascii=False)

# %% [markdown]
# Dans les données du premier livre, chercher où se trouve les informations suivantes (il peut s'agir de dictionnaires imbriqués) :
# - le titre,
# - le prix,
# - la note (_averageRating_)
#
# Afficher ces informations (cf la note ci-dessus pour accéder aux éléments d'un dictionnaire en python).

# %%
title_first_book = data_books[0]["volumeInfo"]["title"]
price_first_book = data_books[0]["saleInfo"]["listPrice"]["amount"]
average_rating_first_book = data_books[0]["volumeInfo"].get("averageRating", "nonexistante")
print(f"Titre : {title_first_book}")
print(f"Prix : {price_first_book}")
print(f"Note : {average_rating_first_book}")
# Out:
# Titre : Encyclopedia of Food and Health
# Prix : 3334
# Note : nonexistante

# %%
# Afficher les infos clés (price, title, rating) pour chaque livres de la liste data_books
for book in data_books:
        volume_info = book.get("volumeInfo", {})
        sale_info = book.get("saleInfo", {})

        title = volume_info.get("title")
        price = sale_info.get("listPrice", {}).get("amount")
        rating = volume_info.get("averegeRating")

        print(f"Titre : {title}")
        print(f"Prix : {price}")
        print(f"Note : {rating}")
        

#The {} here is just the default value in case the key is missing.
#book.get("volumeInfo", {}) → looks for the key "volumeInfo".
#If it exists → returns its dictionary.
#If it does not exist → returns {}
# Out:
# Titre : Encyclopedia of Food and Health
# Prix : 3334
# Note : None
# Titre : Advances in Deep-Fat Frying of Foods
# Prix : 274.3
# Note : None
# Titre : Solid State Fermentation for Foods and Beverages
# Prix : 90.72
# Note : None
# Titre : In-Pack Processed Foods
# Prix : 226.82
# Note : None
# Titre : Current Advances for Development of Functional Foods Modulating Inflammation and Oxidative Stress
# Prix : 184.62
# Note : None
# Titre : Fermented Foods and Beverages of the World
# Prix : 211
# Note : None
# Titre : Biopolymers in Nutraceuticals and Functional Foods
# Prix : 236.32
# Note : None
# Titre : Fermentation Biotechnology for Functional Foods
# Prix : 247.92
# Note : None
# Titre : Functional Foods and their Implications for Health Promotion
# Prix : 163.52
# Note : None
# Titre : Strange Foods
# Prix : 10.99
# Note : None
# Titre : Olives and Olive Oil as Functional Foods
# Prix : 174.99
# Note : None
# Titre : Food Waste to Valuable Resources
# Prix : 163.52
# Note : None
# Titre : Issues of Governance, Security, and Development in Contemporary Africa
# Prix : 118.34
# Note : None
# Titre : Encyclopedia of Food Grains
# Prix : 1968
# Note : None
# Titre : Nutritional Coaching
# Prix : 12.99
# Note : None
# Titre : Cultivation for Climate Change Resilience, Volume 1
# Prix : 75.95
# Note : None
# Titre : Dojo: The Definitive Guide
# Prix : 26.9
# Note : None
# Titre : A Grammar of Emai
# Prix : 185.63
# Note : None
# Titre : Eco-Friendly Energy Processes and Technologies for Achieving Sustainable Development
# Prix : 183.97
# Note : None
# Titre : Allergy Essentials,E-Book
# Prix : 100.21
# Note : None
# Titre : The Rise of Food Charity in Europe
# Prix : 38.99
# Note : None
# Titre : Philosophy Comes to Dinner
# Prix : 54.85
# Note : None
# Titre : Nutraceuticals
# Prix : 242.65
# Note : None
# Titre : Interdisciplinary Behavior and Social Sciences
# Prix : 279.58
# Note : None
# Titre : Present Knowledge in Nutrition
# Prix : 138.2
# Note : None
# Titre : Encyclopedia of Spectroscopy and Spectrometry
# Prix : 2205
# Note : None
# Titre : The Human Side of Service Engineering
# Prix : 58.33
# Note : None
# Titre : Food Science and Technology
# Prix : 121.27
# Note : None
# Titre : International Development
# Prix : 57.37
# Note : None
# Titre : Guinea
# Prix : 8.08
# Note : None
# Titre : Ukrainian Cuisine with an American Touch and Ingredients
# Prix : 11.99
# Note : None
# Titre : Microbiologically Safe Foods
# Prix : 185.47
# Note : None
# Titre : The Emergence of National Food
# Prix : 37.69
# Note : None
# Titre : A Guide to Federal Terms and Acronyms
# Prix : 203.6
# Note : None
# Titre : Spray Drying Techniques for Food Ingredient Encapsulation
# Prix : 171.99
# Note : None
# Titre : On Evil
# Prix : 22.22
# Note : None
# Titre : When Technology Fails
# Prix : 27.81
# Note : None
# Titre : In the Company of Bears
# Prix : 14.36
# Note : None
# Titre : Advertising to Children
# Prix : 94.94
# Note : None
# Titre : Environmentalism, Resistance and Solidarity
# Prix : 52.74
# Note : None

# %% [markdown]
# Créer une liste de dictionnaire contenant les informations de chaque livre sous le format :
# ```
# [{
#     "title": "title0",
#     "price": price_0,
#     "rating": rating_0
# },
# {
#     "title": "title1",
#     "price": price_1,
#     "rating": rating_1
# },
# ...
# ]
# ```

# %%
# Création d'une liste de dictionnaires pour les livres
books_list = []

for book in data_books:
        volume_info = book.get("volumeInfo", {})
        sale_info = book.get("saleInfo", {})

        title = volume_info.get("title")
        price = sale_info.get("listPrice", {}).get("amount")
        rating = volume_info.get("averegeRating")

        books_dict = {
                "title" : title,
                "price" : price,
                "rating" : rating
        }

        books_list.append(books_dict)

# %%
# Créer un dataframe à partir de la liste de dictionnaires
df = pd.DataFrame(books_list)

print(df.head())
# Out:
#                                                title    price rating
# 0                    Encyclopedia of Food and Health  3334.00   None
# 1               Advances in Deep-Fat Frying of Foods   274.30   None
# 2   Solid State Fermentation for Foods and Beverages    90.72   None
# 3                            In-Pack Processed Foods   226.82   None
# 4  Current Advances for Development of Functional...   184.62   None

# %% [markdown]
# Filtrer les livres pour ne conserver que ceux ayant des valeurs pour les colonnes _price_ et _rating_.
#
# - Possibilité d'utiliser la méthode pandas [_dropna_](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)
# - Afficher le dataframe et regarder ce qu'il s'est passé au niveau des index.
# - Utiliser la méthode [_reset_index_](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html) pour réinitialiser les index.

# %%
# Filter les livres pour ne conserver que ceux ayant des valeurs pour les colonnes price et rating
df = df.copy()
df_clean = df.dropna(subset=["price", "rating"])

# Reinitialiser les index du DataFrame
df_clean = df_clean.reset_index(drop=True)
print(df_clean.head())

# Ajouter une colonne availability = False
df_clean["availability"] = False
print(df_clean)
# Out:
# Empty DataFrame
# Columns: [title, price, rating]
# Index: []
# Empty DataFrame
# Columns: [title, price, rating, availability]
# Index: []

# %% [markdown]
# ---
# ## Partie 3 : Insertion des données en base

# %%
# Utiliser sqlite3 pour insérer les données dans la base de données book_store dans la table book
import sqlite3

connection = sqlite3.connect("/home/emese/Briefs_test/scraping/book_store.db")
df_clean.to_sql('book_store', connection, if_exists='replace')
connection.commit()

# %%
# Vérifier que le nombre de livres dans la table correspond au nb de livres scrapés + livres de l'API
# Création d'un curseur pour interagir avec la DB
cursor = connection.cursor()

# Exécuter la requête pour compter le nombre de livre dans la DB
cursor.execute("SELECT COUNT(*) FROM book_store")

# Affichage du résultat
print(cursor.fetchone()[0])

connection.close()
# Out:
# 0
