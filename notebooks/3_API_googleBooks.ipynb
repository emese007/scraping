# %% [markdown]
# # Utiliser l'API Google Books pour récupérer des données de livres
#
# ## Partie 1 : Comprendre les API

# %% [markdown]
# ### a. Qu’est-ce qu’une API ?
# - API = Application Programming Interface
# - Une API est une interface qui permet à un programme d’accéder aux fonctionnalités ou aux données d’un autre service, sans avoir besoin de connaître son fonctionnement interne.
# - Exemple : l’API Google Books met à disposition des données sur des millions de livres, que l’on peut interroger depuis un programme Python.
# - On envoie une **requête** (question) à l’API, elle nous répond avec des **données** (souvent en JSON)

# %% [markdown]
# ### b. Qu’est-ce qu’une requête HTTP ?
# - HTTP = HyperText Transfer Protocol – c’est le protocole qui permet à des machines (navigateur, script Python, application mobile...) de communiquer avec des serveurs sur Internet.
# - Une requête HTTP est un message envoyé depuis un client (comme un navigateur ou un programme Python) vers un serveur web pour lui demander quelque chose.
# - Quand on ouvre un site web ou que l'on demande des données à une API, on envoie une **requête HTTP**, généralement de type :
#
#     - **GET** → pour demander des données
#     - **POST** → pour envoyer des données
#     - **PUT**, **DELETE**, etc.
#
# - L’API Google Books utilise principalement des requêtes de type GET, comme si on entrait une URL dans un navigateur pour demander des infos.
# - Une URL de requête API suit une structure bien définie :
#
# `<URL de base> ? <paramètre1>=<valeur1> & <paramètre2>=<valeur2> & ...`
#
# - URL de base : adresse du point d’entrée de l’API, aussi appelée **endpoint**.
# - ? : sépare l’URL de base des paramètres de requête.
# - Paramètres de requête (query parameters) : ajoutés sous forme de paires clé=valeur. Chaque paramètre est séparé par &.  Les paramètres possibles sont disponibles dans la documentation de chaque API.

# %% [markdown]
# ### c. Réponse
#
# Quand on envoie une requête GET à une API, on demande au serveur de renvoyer une ressource.
#
# La réponse de ce serveur comporte deux parties essentielles :

# %% [markdown]
# 1. **Le code de status de réponse (HTTP status code)**
#
# C’est un nombre à 3 chiffres qui indique si la requête a réussi ou non.
#
# --> [Liste des codes possibles](https://developer.mozilla.org/fr/docs/Web/HTTP/Reference/Status) et leur signification

# %% [markdown]
# 2. **Le contenu de la réponse (le "corps")**
#
# C’est ici que se trouvent les données demandées.
#
# Ce contenu est souvent au format JSON (JavaScript Object Notation), c’est-à-dire une structure clé-valeur que Python peut facilement lire.
#
# Exemple d'un format JSON :
# ```json
# {
#   "items": [
#     {
#       "tripInfo": {
#         "country": "France",
#         "cities": ["Montpellier", "Marseille"],
#         "nb_photo_taken": 200,
#         "language": "fr"
#       }
#     }
#   ]
# }
# ```

# %% [markdown]
# ---
# ## Partie 2 : Requêter Google Books API
#
# Dans cette partie vous allez :
# - Faire une requête HTTP pour interroger l'API Google Books à l'aide de la bibliothèque python _requests_,
# - Vérifier le code de status de la réponse,
# - Traiter le corps de la réponse à l'aide de la bibliothèque python _json_,
# - Utiliser _pandas_ pour convertir les données reçues en dataframe.

# %%
# Importer les bibliothèques nécessaires
import requests
import json
import pandas as pd

# %% [markdown]
# Pour interroger une API, un certain nombre de paramètres et filtres définis dans la documentation peuvent être utilisés.
#
# En utilisant la [documentation](https://developers.google.com/books/docs/v1/using?hl=fr#WorkingVolumes) de l'API Google Books, définir le dictionnaire de paramètres permettant de faire une recherche sur :
# - la chaîne de texte : "food",
# - il doit s'agir d'un e-book avec un prix d'achat,
# - le nombre maximal de résultats à renvoyer est de 40,
# - les résultats doivent être triés par pertinence.

# %%
# URL de l'API Google Books
url = "https://www.googleapis.com/books/v1/volumes"

# Dictionnaire de paramètres pour la requête 
params = {"q": "food",
          "filter": "paid-ebooks",
          "maxResults": 40,
          "orderBy": "relevance"
          }

#url = "https://www.googleapis.com/books/v1/volumes?q=food&filter=paid-ebooks&maxResults=40&orderBy:relevance"

# %% [markdown]
# En utilisant la documentation de la bibliothèque [_requests_](https://requests.readthedocs.io/en/latest/user/quickstart/):
# - implémenter la requête HTTP _get_  avec les paramètres sur l'URL définie ci-dessus,
# - vérifier le code de réponse HTTP.

# %%
# Requêter l'API Google Books
response = requests.get(url, params=params)

# Vérifier le code de statut de la réponse
print(response.status_code)

#Ici on envoie une requête HTTP GET vers l’API Google Books
#La bibliothèque requests va construire automatiquement l’URL complète : "https://www.googleapis.com/books/v1/volumes?q=food&filter=paid-ebooks&maxResults=40&orderBy:relevance"
#Puis elle envoie la requête au serveur Google.
#Le résultat est stocké dans l’objet response.
# Out:
# 200

# %% [markdown]
# Récupérer et observer le coeur de la réponse via l'objet _response_ créé précédemment.

# %%
# Récupérer le coeur de la réponse
data_books_raw = response.json()

# Afficher les données récupérées
#print(data_books_raw)

# Afficher le type de la variable data_books_raw
#print(type(data_books_raw))

#La méthode .json() de l’objet response :
#lit le corps de la réponse HTTP (qui est en format JSON, c’est-à-dire du texte structuré)
#et le convertit en dictionnaire Python (dict) automatiquement.

{
  "kind": "books#volumes",
  "totalItems": 123,
  "items": [ {...} ]
}

#print(data_books_raw.keys())
print(json.dumps(data_books_raw, indent=2))

#Donc en résumé :
#response.json() → convertit le JSON en dict Python
#print(...) → affiche les données
#type(...) → confirme la structure (dict)
# Out:
# {
#   "kind": "books#volumes",
#   "totalItems": 1000000,
#   "items": [
#     {
#       "kind": "books#volume",
#       "id": "O-t9BAAAQBAJ",
#       "etag": "D9+ivUDCftU",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/O-t9BAAAQBAJ",
#       "volumeInfo": {
#         "title": "Encyclopedia of Food and Health",
#         "publisher": "Academic Press",
#         "publishedDate": "2015-08-26",
#         "description": "Approx.3876 pages Approx.3876 pages",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9780123849533"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "0123849535"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": true
#         },
#         "pageCount": 2379,
#         "printType": "BOOK",
#         "categories": [
#           "Technology & Engineering"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "2.6.5.0.preview.1",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=O-t9BAAAQBAJ&pg=RA2-PA1&dq=food&hl=&as_brr=6&cd=1&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 3334,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 3334,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&rdid=book-O-t9BAAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 3334000000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 3334000000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Encyclopedia_of_Food_and_Health-sample-pdf.acsm?id=O-t9BAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=O-t9BAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>food</b>. Importance. of. <b>Food</b>. Classification. and. Description. The preparation of reliable data on <b>food</b> requires precise iden- tification of <b>foods</b>. Even data of good quality can be a source of error if they are derived from <b>foods</b> that are&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "SKt_u35t9hsC",
#       "etag": "XGqEXsb95kE",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/SKt_u35t9hsC",
#       "volumeInfo": {
#         "title": "When Technology Fails",
#         "subtitle": "A Manual for Self-Reliance, Sustainability, and Surviving the Long Emergency, 2nd Edition",
#         "authors": [
#           "Matthew Stein"
#         ],
#         "publisher": "Chelsea Green Publishing",
#         "publishedDate": "2008-08-18",
#         "description": "There\u2019s never been a better time to be prepared. \u201cThis book is an indispensable basic manual for the real-life issues that await us in the decades to come. . . [A] treasure trove of practical wisdom.\u201d\u2014James Howard Kunstler, author of The Geography of Nowhere Matthew Stein\u2019s comprehensive primer on sustainable living skills\u2014from food and water to shelter and energy to first-aid and crisis-management skills\u2014prepares you to embark on the path toward sustainability. But unlike any other book, Stein not only shows you how to live green in seemingly stable times, but to live in the face of potential disasters, lasting days or years, coming in the form of social upheaval, economic meltdown, or environmental catastrophe. When Technology Fails covers the gamut. Inside, you\u2019ll learn: The basics of installing a renewable energy system for your home or business How to find and sterilize water in the face of utility failure How to keep warm if you\u2019ve been left temporarily homeless Practical information for dealing with water-quality issues Alternative health and first-aid techniques Each chapter describes skills for self-reliance in good times and bad. Chapters Include: A survey of the risks to the status quo Supplies and preparation for short- and long-term emergencies Emergency measures for survival Prepping water, food, shelter, and clothing First aid, low-tech medicine, and healing Securing energy, heat, and power Metalworking Utensils and storage Low-tech chemistry engineering, machines, and materials Fully revised and expanded, When Technology Fails ends on a positive, proactive note with a chapter on \u201cMaking the Shift to Sustainability,\u201d which offers practical suggestions for changing our world on personal, community and global levels. \"When Technology Fails is a massive project done well. First the book gives a superb presentation of WHY one should be more aware and prepared--and then HOW one should go about this. The scope of this book... is thorough.\"\u2014John McPherson, author, Primitive Wilderness Living and Survival Skills",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781603580953"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1603580956"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 514,
#         "printType": "BOOK",
#         "categories": [
#           "Social Science"
#         ],
#         "averageRating": 3,
#         "ratingsCount": 2,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "2.5.4.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=SKt_u35t9hsC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=SKt_u35t9hsC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=SKt_u35t9hsC&pg=PA55&dq=food&hl=&as_brr=6&cd=2&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=SKt_u35t9hsC&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=SKt_u35t9hsC"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 27.82,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 27.82,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=SKt_u35t9hsC&rdid=book-SKt_u35t9hsC&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 27820000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 27820000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/When_Technology_Fails-sample-epub.acsm?id=SKt_u35t9hsC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/When_Technology_Fails-sample-pdf.acsm?id=SKt_u35t9hsC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=SKt_u35t9hsC&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>foods</b>. I suggest using quality supplements manu- factured from live <b>foods</b> wherever possible (check your local health <b>food</b> store). \u2022 Fuels, lighting sources, camping gear. Camping gear can provide you with portable shelter and materials&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "RgU9u9oUSDQC",
#       "etag": "s/AcAVIbgd4",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/RgU9u9oUSDQC",
#       "volumeInfo": {
#         "title": "Advances in Deep-Fat Frying of Foods",
#         "authors": [
#           "Servet Gulum Sumnu",
#           "Serpil Sahin"
#         ],
#         "publisher": "CRC Press",
#         "publishedDate": "2008-12-17",
#         "description": "Battered fried foods consistently remain in high demand despite concerns about their health aspects, prompting food processors to develop new methods and alternative oils and batters in the name of healthy, tasty fried foods and high-performance, cost-effective frying oil. With contributions from an international panel of food technology authoritie",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781420055597"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1420055593"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 330,
#         "printType": "BOOK",
#         "categories": [
#           "Technology & Engineering"
#         ],
#         "averageRating": 5,
#         "ratingsCount": 1,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.3.6.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=RgU9u9oUSDQC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=RgU9u9oUSDQC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=RgU9u9oUSDQC&pg=PA140&dq=food&hl=&as_brr=6&cd=3&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=RgU9u9oUSDQC&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=RgU9u9oUSDQC"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 274.3,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 216.28,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=RgU9u9oUSDQC&rdid=book-RgU9u9oUSDQC&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 274300000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 216280000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Advances_in_Deep_Fat_Frying_of_Foods-sample-epub.acsm?id=RgU9u9oUSDQC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Advances_in_Deep_Fat_Frying_of_Foods-sample-pdf.acsm?id=RgU9u9oUSDQC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=RgU9u9oUSDQC&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>Food</b> Engineering 43 : 147\u201354 . 2000b . Water loss and oil uptake as a function of frying time . Journal of <b>Food</b> Engi- neering 44 : 39\u201346 . Krokida , M.K. , V. Oreopoulou , Z.B. Maroulis , and D. Marinos - Kouris . 2001. Colour changes&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "CSHOBQAAQBAJ",
#       "etag": "jjz37aO/QS8",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/CSHOBQAAQBAJ",
#       "volumeInfo": {
#         "title": "Solid State Fermentation for Foods and Beverages",
#         "authors": [
#           "Jian Chen",
#           "Yang Zhu"
#         ],
#         "publisher": "CRC Press",
#         "publishedDate": "2013-11-23",
#         "description": "Although one of the oldest microbial technologies used in food processing, solid-state fermentation (SSF) had, until recently, fallen out of favor. However, based on a series of established mathematical models, new design concepts for SSF bioreactors and process control strategies have been proposed, allowing SSF technology to reach new levels. Sol",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781439844977"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1439844976"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": true
#         },
#         "pageCount": 404,
#         "printType": "BOOK",
#         "categories": [
#           "Science"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.4.4.0.preview.1",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=CSHOBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=CSHOBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=CSHOBQAAQBAJ&pg=PA350&dq=food&hl=&as_brr=6&cd=4&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=CSHOBQAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=CSHOBQAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 90.72,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 69.41,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=CSHOBQAAQBAJ&rdid=book-CSHOBQAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 90720000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 69410000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Solid_State_Fermentation_for_Foods_and_B-sample-pdf.acsm?id=CSHOBQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=CSHOBQAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>food</b> shortage problem. With the adaptation of <b>food</b> fermentation, the indigenous self- help famine relief has been successfully achieved. Most fermented <b>foods</b> appear to have been developed to ensure the nutrition of the family in the dry&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "uvaiAgAAQBAJ",
#       "etag": "wXNF+6mzr54",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/uvaiAgAAQBAJ",
#       "volumeInfo": {
#         "title": "In-Pack Processed Foods",
#         "subtitle": "Improving Quality",
#         "authors": [
#           "P Richardson"
#         ],
#         "publisher": "Elsevier",
#         "publishedDate": "2008-06-13",
#         "description": "Recent developments have enabled the production of in-pack processed foods with improved sensory quality as well as new types of heat-preserved products packaged in innovative containers. This book reviews these advances in packaging formats and processing technologies and their application to produce higher quality, safer foods.Opening chapters cover innovative can designs and non-traditional packaging formats, such as retort pouches. The second part of the book reviews the developments in processing and process control technology required by newer types of packaging. Part three addresses the safety of in-pack processed foods, including concerns over pathogens and hazardous compounds in processed foods. The book concludes with chapters on novel methods to optimise the quality of particular types of in-pack processed foods such as fruit and vegetables, meat, poultry and fish products.In-pack processed foods: improving quality is a valuable reference for professionals involved in the manufacture of this important group of food products and those researching in this area. - Reviews advances in packaging formats and processing technologies - Covers innovative can designs and non-traditional packaging formats - Examines the safety of in-pack processed foods, including concerns over pathogens",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781845694692"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1845694694"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 428,
#         "printType": "BOOK",
#         "categories": [
#           "Technology & Engineering"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.4.3.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=uvaiAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=uvaiAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=uvaiAgAAQBAJ&pg=PA401&dq=food&hl=&as_brr=6&cd=5&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=uvaiAgAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=uvaiAgAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 226.82,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 158.77,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=uvaiAgAAQBAJ&rdid=book-uvaiAgAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 226820000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 158770000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/In_Pack_Processed_Foods-sample-epub.acsm?id=uvaiAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/In_Pack_Processed_Foods-sample-pdf.acsm?id=uvaiAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=uvaiAgAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>Food</b> Science, 45(6), pp. 1517\u20131521. Parry, D. A. 1970, Fish as <b>food</b>, in Proteins as Human <b>Foods</b>, R. A. Lawrie, ed., Butterworths, London, p. 365. Pedrosa-Menabrito, A. and Regenstein, J. M. 1990, Shelf-life Extension of Fresh Fish&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "NmI7EAAAQBAJ",
#       "etag": "dDVylFgwOJ0",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/NmI7EAAAQBAJ",
#       "volumeInfo": {
#         "title": "Current Advances for Development of Functional Foods Modulating Inflammation and Oxidative Stress",
#         "authors": [
#           "Blanca Hernandez-Ledesma",
#           "Cristina Martinez-Villaluenga"
#         ],
#         "publisher": "Academic Press",
#         "publishedDate": "2021-12-03",
#         "description": "Current Advances for Development of Functional Foods Modulating Inflammation and Oxidative Stress presents the nutritional and technological aspects related to the development of functional foods with anti-inflammatory and antioxidant effects. Specifically, analytical approaches for the characterization of anti-inflammatory and antioxidant properties of healthy foods and functional constituents, as well as technological strategies for the extraction of compounds and fractions from raw materials to produce anti-inflammatory and antioxidant ingredients are addressed. In addition, the molecular mechanisms by which foods and their components can modulate inflammation and their oxidative stress effects on disease prevention are explored. Finally, clinical research addressing nutritional needs in pathological subjects with inflammatory diseases are considered. - Covers methods of analysis and extraction of anti-inflammatory and antioxidant compounds - Offers an overview of the main anti-inflammatory and antioxidant compounds in foods - Provides a guide on the mechanisms of action and health benefits of anti-inflammatory and antioxidant dietary bioactives",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9780128225844"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "012822584X"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 676,
#         "printType": "BOOK",
#         "categories": [
#           "Technology & Engineering"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.5.5.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=NmI7EAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=NmI7EAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=NmI7EAAAQBAJ&pg=PA81&dq=food&hl=&as_brr=6&cd=6&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=NmI7EAAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=NmI7EAAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 184.62,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 129.23,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=NmI7EAAAQBAJ&rdid=book-NmI7EAAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 184620000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 129230000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Current_Advances_for_Development_of_Func-sample-epub.acsm?id=NmI7EAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Current_Advances_for_Development_of_Func-sample-pdf.acsm?id=NmI7EAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=NmI7EAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>foods</b>. Application of multiple emulsions to formulate the functional <b>food</b> products have been recognized for several years such as the development of low-fat imitation creams, fat reduced mayonnaise (Moussaoui et al., 2017), low-fat&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "MJTLBQAAQBAJ",
#       "etag": "7VpAQ3qaJdA",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/MJTLBQAAQBAJ",
#       "volumeInfo": {
#         "title": "Fermented Foods and Beverages of the World",
#         "authors": [
#           "Jyoti Prakash Tamang",
#           "Kasipathy Kailasapathy"
#         ],
#         "publisher": "CRC Press",
#         "publishedDate": "2010-07-01",
#         "description": "Did you know? It's estimated that fermentation practices have been around since as early as 6000 BC, when wine was first being made in Caucasus and Mesopotamia. Today, there are roughly 5000 varieties of fermented foods and beverages prepared and consumed worldwide, which accounts for between five and forty percent of daily meals. Fermented Foods a",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781420094961"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1420094963"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": true
#         },
#         "pageCount": 462,
#         "printType": "BOOK",
#         "categories": [
#           "Technology & Engineering"
#         ],
#         "averageRating": 5,
#         "ratingsCount": 1,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.3.3.0.preview.1",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=MJTLBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=MJTLBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=MJTLBQAAQBAJ&pg=PA81&dq=food&hl=&as_brr=6&cd=7&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=MJTLBQAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=MJTLBQAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 211,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 165.64,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=MJTLBQAAQBAJ&rdid=book-MJTLBQAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 211000000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 165640000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Fermented_Foods_and_Beverages_of_the_Wor-sample-pdf.acsm?id=MJTLBQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=MJTLBQAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>Food</b> Composition and Analysis 20 : 113\u2013118 . Silla Santos , M.H. 1996. Biogenic amines : Their importance in <b>foods</b> . International Journal of <b>Food</b> Microbiology 29 : 213\u2013231 . Silva , C.F. , L.R. Batista , L.M. Abreu , E.S. Dias , and&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "mRebEAAAQBAJ",
#       "etag": "RRZq6vBRpD8",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/mRebEAAAQBAJ",
#       "volumeInfo": {
#         "title": "Biopolymers in Nutraceuticals and Functional Foods",
#         "authors": [
#           "Sreerag Gopi",
#           "Preetha Balakrishnan",
#           "Matej Bra\u010di\u010d"
#         ],
#         "publisher": "Royal Society of Chemistry",
#         "publishedDate": "2022-11-04",
#         "description": "As a result of their unique physical properties, biological membrane mimetics such as biopolymers are used in a broad range of scientific and technological applications. This comprehensive book covers new applications of biopolymers in the research and development of industrial scale nutraceutical and functional food grade products. All the major food biopolymers are included, from plant, animal and marine sources. Coverage also includes biopolymer-based drug delivery mechanisms intended for biological applications such as bio-detection of pathogens, fluorescent biological labels, and drug and gene delivery. This is the first interdisciplinary book to address this area specifically and is essential reading for those who produce the functional biopolymer materials as well as those who seek to incorporate them into appropriate nutraceutical, food and drug delivery products.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781839168055"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1839168056"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 495,
#         "printType": "BOOK",
#         "categories": [
#           "Technology & Engineering"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.2.3.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=mRebEAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=mRebEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=mRebEAAAQBAJ&pg=PT334&dq=food&hl=&as_brr=6&cd=8&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=mRebEAAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=mRebEAAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 236.32,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 165.42,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=mRebEAAAQBAJ&rdid=book-mRebEAAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 236320000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 165420000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Biopolymers_in_Nutraceuticals_and_Functi-sample-epub.acsm?id=mRebEAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Biopolymers_in_Nutraceuticals_and_Functi-sample-pdf.acsm?id=mRebEAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=mRebEAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>Food</b> and Health, ed. B. Caballero, P. Finglas and F. Toldr\u00e1, Elsevier Inc., Amsterdam, 1st edn, 2015, pp. 294\u2013300. 11. D. Mudgil, S. Barak and B. S. Khatkar, Guar Gum: processing, properties and <b>food</b> applications - A Review, J. <b>Food</b> Sci&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "6iyIEQAAQBAJ",
#       "etag": "c2SCK6hv78I",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/6iyIEQAAQBAJ",
#       "volumeInfo": {
#         "title": "Fermentation Biotechnology for Functional Foods",
#         "authors": [
#           "Kalidas Shetty",
#           "Lena G\u00e1lvez Ranilla"
#         ],
#         "publisher": "CRC Press",
#         "publishedDate": "2025-10-31",
#         "description": "Fermentation-based processing advanced with global food systems as humanity started to organize the domestication of agriculture from plant and animal sources. These advances emerged across regions of the world from river valley civilizations in Asia (Mesopotamia, India and China) and Africa (Egypt) to Meso-American civilizations. As food crops and animal foods emerged from domestication to advancements in post-harvest processing stages, growth of invisible microbial systems led to modified foods that aligned with local palates of the communities. This in several cases became part of food systems, as it added a mode of preservation and improved the food quality that was preferred by each community. This is how the early genesis of fermented foods from grains, fruits and vegetables to animal meats and milk products became an integral part of early civilizations over 4000 years ago and has now carried over and further developed across many countries in every region of the world. The foundations of these food fermentations are now an integral part of modern food advances as preferred food substrates and the microbial interactions that drive the metabolic processes in defined food matrixes are being scientifically advanced. This book focuses on bringing together diverse emergences and advancements of fermented foods across different regions of the world and how the metabolic processes associated with fermentation in several cases add health-relevant functional qualities across different food matrixes. This book contains 26 chapters from the Americas, Africa, Europe and Asia, bringing together the fermentation processes of diverse food substrates and their microbial processing and in several cases providing health-targeted functional benefits. Key Features: Discusses the rationale and basis of fermented food systems from across 26 diverse regions of the world with examples from the Americas, Asia, Europe and Africa Presents historical plant and animal food substrates and the metabolic processes of their fermentation across traditions of a range of countries Covers traditional food fermentations across diverse food substrates that have potentially health-relevant functional benefits Reflects and presents the role of historical, cultural and traditional food concepts of a diverse range of countries with many novel examples and how they have influenced health-relevant functional benefits Discusses the relevance of metabolic concepts of fermented and functional foods in advancing healthy food concepts This book is important for food scientists, nutritionists and the health care sector, but beyond this, it is also relevant for a wider global audience interested in a holistic health approach from food systems where examples of fermentation experience can inform new natural processing strategies to improve food quality and health.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781040410448"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1040410448"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": true
#         },
#         "pageCount": 497,
#         "printType": "BOOK",
#         "categories": [
#           "Technology & Engineering"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=6iyIEQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=6iyIEQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=6iyIEQAAQBAJ&pg=PA158&dq=food&hl=&as_brr=6&cd=9&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=6iyIEQAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=6iyIEQAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 247.92,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 195.18,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=6iyIEQAAQBAJ&rdid=book-6iyIEQAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 247920000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 195180000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Fermentation_Biotechnology_for_Functiona-sample-pdf.acsm?id=6iyIEQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=6iyIEQAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>Food</b> Sciences and Nutrition 61, no. 2: 125\u2013137. Hassan, Z. 1980. Pekasam\u2014A fermented fish product (in Peninsular Malaysia). In Seminar on Modernization of Malaysian Cottage <b>Food</b> Industries. Serdang: Universiti Pertanian Malaysia. Ho&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "NGI7EAAAQBAJ",
#       "etag": "uxO41tvhiNY",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/NGI7EAAAQBAJ",
#       "volumeInfo": {
#         "title": "Functional Foods and their Implications for Health Promotion",
#         "authors": [
#           "Ioannis Zabetakis",
#           "Ronan Lordan",
#           "Alexandros Tsoupras",
#           "Dipak Ramji"
#         ],
#         "publisher": "Academic Press",
#         "publishedDate": "2022-12-03",
#         "description": "Functional Foods and Their Implications for Health Promotion presents functional foods, from raw ingredients to the final product, providing a detailed explanation on how these foods work and an overview of their impact on health. The book presents the functions of food against disease and discusses how healthier foods can be produced. Broken into four parts, the book presents a deep dive into plant-derived functional foods, dairy foods, marine food and beverages. The book includes case studies, applications, literature reviews and coverage of recent developments.Intended for nutritionists, dieticians, food technologists, as well as students and researchers working in nutrition, dietetics, and food science, this book is sure to be a welcomed resource. - Uses flow diagrams to highlight the effects of processing on produced functional foods - Combines information on the production/formulation of the food with data on bioactivities and bioavailability - Presents whole foods and not food components while also focusing on functionality and availability",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9780128238127"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "0128238127"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 406,
#         "printType": "BOOK",
#         "categories": [
#           "Technology & Engineering"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.9.9.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=NGI7EAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=NGI7EAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=NGI7EAAAQBAJ&pg=PA285&dq=food&hl=&as_brr=6&cd=10&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=NGI7EAAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=NGI7EAAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 163.52,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 114.46,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=NGI7EAAAQBAJ&rdid=book-NGI7EAAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 163520000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 114460000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Functional_Foods_and_their_Implications-sample-epub.acsm?id=NGI7EAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Functional_Foods_and_their_Implications-sample-pdf.acsm?id=NGI7EAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=NGI7EAAAQBAJ&hl=&as_brr=6&source=gbs_api",
# ...
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781603586009"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1603586008"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 201,
#         "printType": "BOOK",
#         "categories": [
#           "Nature"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.5.5.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=ck9HBAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=ck9HBAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=ck9HBAAAQBAJ&pg=PT186&dq=food&hl=&as_brr=6&cd=37&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=ck9HBAAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=ck9HBAAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 14.36,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 14.36,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=ck9HBAAAQBAJ&rdid=book-ck9HBAAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 14360000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 14360000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/In_the_Company_of_Bears-sample-epub.acsm?id=ck9HBAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/In_the_Company_of_Bears-sample-pdf.acsm?id=ck9HBAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=ck9HBAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>food</b> shortages. Still, our forests, for a number of reasons, fail to meet the <b>food</b> requirements for all of the bears all of the time. Some of the reasons derive from how we manage the land. As forests are logged off, the second growth&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "nx1vBAAAQBAJ",
#       "etag": "OV3Esp6ufes",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/nx1vBAAAQBAJ",
#       "volumeInfo": {
#         "title": "Advertising to Children",
#         "subtitle": "New Directions, New Media",
#         "authors": [
#           "M. Blades",
#           "C. Oates",
#           "F. Blumberg",
#           "B. Gunter"
#         ],
#         "publisher": "Springer",
#         "publishedDate": "2014-08-29",
#         "description": "This important source for students, researchers, advertisers and parents reviews the debates and presents new research about advertising to children. Chapters cover food and alcohol advertising, the effects of product placement and new media advertising, and the role of parents and teachers in helping children to learn more about advertising.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781137313256"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1137313250"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 264,
#         "printType": "BOOK",
#         "categories": [
#           "Psychology"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.7.5.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=nx1vBAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=nx1vBAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=nx1vBAAAQBAJ&pg=PA57&dq=food&hl=&as_brr=6&cd=38&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=nx1vBAAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=nx1vBAAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 94.94,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 63.29,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=nx1vBAAAQBAJ&rdid=book-nx1vBAAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 94940000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 63290000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Advertising_to_Children-sample-epub.acsm?id=nx1vBAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Advertising_to_Children-sample-pdf.acsm?id=nx1vBAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=nx1vBAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>food</b> adverts and brand recognition Effects on <b>food</b> preferences and choice Borzekowski and Robinson (2001) carried out a randomized, controlled trial in which they showed preschool children a videotape of a cartoon either with or without&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "wBmuAgAAQBAJ",
#       "etag": "V2MoLZtNg+A",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/wBmuAgAAQBAJ",
#       "volumeInfo": {
#         "title": "Environmentalism, Resistance and Solidarity",
#         "subtitle": "The Politics of Friends of the Earth International",
#         "authors": [
#           "B. Doherty",
#           "T. Doyle"
#         ],
#         "publisher": "Springer",
#         "publishedDate": "2013-10-16",
#         "description": "Drawing from a rich mix of survey data, interviews, and access to internal meetings, Brian Doherty and Timothy Doyle show how FoEI has developed a distinctive environmentalism, which allows for the differences in context between regions and across the North-South divide.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781137316714"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1137316713"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 260,
#         "printType": "BOOK",
#         "categories": [
#           "Political Science"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.4.4.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=wBmuAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=wBmuAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=wBmuAgAAQBAJ&pg=PA157&dq=food&hl=&as_brr=6&cd=39&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=wBmuAgAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=wBmuAgAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 52.74,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 34.28,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=wBmuAgAAQBAJ&rdid=book-wBmuAgAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 52740000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 34280000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Environmentalism_Resistance_and_Solidari-sample-epub.acsm?id=wBmuAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Environmentalism_Resistance_and_Solidari-sample-pdf.acsm?id=wBmuAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=wBmuAgAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... <b>food</b> system and &#39;the need to refocus attention on the billion and a half men and women who produce the <b>food</b> we all eat&#39;.3 FoEI was one of the forum&#39;s organizers, with REDES/FoE Uruguay&#39;s Mart\u00edn Drago sitting on the International&nbsp;..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "0pDGAAAAQBAJ",
#       "etag": "3Sfnc2ljEos",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/0pDGAAAAQBAJ",
#       "volumeInfo": {
#         "title": "Risk Regulation in the United States and European Union",
#         "subtitle": "Controlling Chaos",
#         "authors": [
#           "A. Luedtke",
#           "L. Svedin",
#           "Thad E. Hall"
#         ],
#         "publisher": "Springer",
#         "publishedDate": "2010-06-07",
#         "description": "Globalization and technology have altered public fears and changed expectations of how government should make people safer. This book analyzes how Europeans and Americans perceive and regulate risk. The authors show how public fears about risk are filtered through political systems to pressure governments to insure against risk.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9780230109476"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "0230109470"
#           }
#         ],
#         "readingModes": {
#           "text": true,
#           "image": true
#         },
#         "pageCount": 220,
#         "printType": "BOOK",
#         "categories": [
#           "Business & Economics"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "4.7.5.0.preview.3",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=0pDGAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=0pDGAAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.fr/books?id=0pDGAAAAQBAJ&pg=PA104&dq=food&hl=&as_brr=6&cd=40&source=gbs_api",
#         "infoLink": "https://play.google.com/store/books/details?id=0pDGAAAAQBAJ&source=gbs_api",
#         "canonicalVolumeLink": "https://play.google.com/store/books/details?id=0pDGAAAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "FR",
#         "saleability": "FOR_SALE",
#         "isEbook": true,
#         "listPrice": {
#           "amount": 52.74,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amount": 34.28,
#           "currencyCode": "EUR"
#         },
#         "buyLink": "https://play.google.com/store/books/details?id=0pDGAAAAQBAJ&rdid=book-0pDGAAAAQBAJ&rdot=1&source=gbs_api",
#         "offers": [
#           {
#             "finskyOfferType": 1,
#             "listPrice": {
#               "amountInMicros": 52740000,
#               "currencyCode": "EUR"
#             },
#             "retailPrice": {
#               "amountInMicros": 34280000,
#               "currencyCode": "EUR"
#             },
#             "giftable": true
#           }
#         ]
#       },
#       "accessInfo": {
#         "country": "FR",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Risk_Regulation_in_the_United_States_and-sample-epub.acsm?id=0pDGAAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.fr/books/download/Risk_Regulation_in_the_United_States_and-sample-pdf.acsm?id=0pDGAAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=0pDGAAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "... (<b>Food</b> Standards Agency 2008a). In 2006 the EU introduced its newest set of regulations pertaining to <b>food</b> production hygiene. This regulation package included Regulation (EC) 852/2004 on the hygiene of foodstuffs, Regulation (EC) 853&nbsp;..."
#       }
#     }
#   ]
# }

# %% [markdown]
# - Les données relatives aux livres récupérées sont accessibles dans la clé 'items',
# - Récupérer les données relatives aux livres dans la variable data_books.
#
# **NOTE**
#
# Il existe 2 méthodes pour accéder aux valeurs d'une clé ("nom_de_la_clé") d'un dictionnaire python :
# - `mon_dict["nom_de_la_clé"]`: si "nom_de_la_clé" n'est pas présent dans le dictionnaire, cela retourne une erreur.
# - `mon_dict.get("nom_de_la_clé")` : si "nom_de_la_clé" n'est pas présent dans le dictionnaire, cela renvoie None par défault.
# Il est aussi possible d'indiquer comme second argument la variable à renvoyer si la clé n'est pas présente :
#
# `mon_dict.get("nom_de_la_clé", "clé inexistante")`
#
# Privilégier la seconde méthode car certaines clés peuvent ne pas exister.
#
# --> [Lien ressource](https://w3schools.tech/fr/tutorial/python/python_access_dictionary_items) : accès au clé/valeurs d'un dictionnaire python

# %%
# Récupérer les données relatives aux livres via la clé 'items'
data_books = data_books_raw["items"]

# Afficher le type de la variable data_books
print(type(data_books))

print(json.dumps(data_books, indent=2))
# Out:
# <class 'list'>
# [
#   {
#     "kind": "books#volume",
#     "id": "O-t9BAAAQBAJ",
#     "etag": "D9+ivUDCftU",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/O-t9BAAAQBAJ",
#     "volumeInfo": {
#       "title": "Encyclopedia of Food and Health",
#       "publisher": "Academic Press",
#       "publishedDate": "2015-08-26",
#       "description": "Approx.3876 pages Approx.3876 pages",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9780123849533"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "0123849535"
#         }
#       ],
#       "readingModes": {
#         "text": false,
#         "image": true
#       },
#       "pageCount": 2379,
#       "printType": "BOOK",
#       "categories": [
#         "Technology & Engineering"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "2.6.5.0.preview.1",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=O-t9BAAAQBAJ&pg=RA2-PA1&dq=food&hl=&as_brr=6&cd=1&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 3334,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 3334,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&rdid=book-O-t9BAAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 3334000000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 3334000000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": false
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Encyclopedia_of_Food_and_Health-sample-pdf.acsm?id=O-t9BAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=O-t9BAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>food</b>. Importance. of. <b>Food</b>. Classification. and. Description. The preparation of reliable data on <b>food</b> requires precise iden- tification of <b>foods</b>. Even data of good quality can be a source of error if they are derived from <b>foods</b> that are&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "SKt_u35t9hsC",
#     "etag": "XGqEXsb95kE",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/SKt_u35t9hsC",
#     "volumeInfo": {
#       "title": "When Technology Fails",
#       "subtitle": "A Manual for Self-Reliance, Sustainability, and Surviving the Long Emergency, 2nd Edition",
#       "authors": [
#         "Matthew Stein"
#       ],
#       "publisher": "Chelsea Green Publishing",
#       "publishedDate": "2008-08-18",
#       "description": "There\u2019s never been a better time to be prepared. \u201cThis book is an indispensable basic manual for the real-life issues that await us in the decades to come. . . [A] treasure trove of practical wisdom.\u201d\u2014James Howard Kunstler, author of The Geography of Nowhere Matthew Stein\u2019s comprehensive primer on sustainable living skills\u2014from food and water to shelter and energy to first-aid and crisis-management skills\u2014prepares you to embark on the path toward sustainability. But unlike any other book, Stein not only shows you how to live green in seemingly stable times, but to live in the face of potential disasters, lasting days or years, coming in the form of social upheaval, economic meltdown, or environmental catastrophe. When Technology Fails covers the gamut. Inside, you\u2019ll learn: The basics of installing a renewable energy system for your home or business How to find and sterilize water in the face of utility failure How to keep warm if you\u2019ve been left temporarily homeless Practical information for dealing with water-quality issues Alternative health and first-aid techniques Each chapter describes skills for self-reliance in good times and bad. Chapters Include: A survey of the risks to the status quo Supplies and preparation for short- and long-term emergencies Emergency measures for survival Prepping water, food, shelter, and clothing First aid, low-tech medicine, and healing Securing energy, heat, and power Metalworking Utensils and storage Low-tech chemistry engineering, machines, and materials Fully revised and expanded, When Technology Fails ends on a positive, proactive note with a chapter on \u201cMaking the Shift to Sustainability,\u201d which offers practical suggestions for changing our world on personal, community and global levels. \"When Technology Fails is a massive project done well. First the book gives a superb presentation of WHY one should be more aware and prepared--and then HOW one should go about this. The scope of this book... is thorough.\"\u2014John McPherson, author, Primitive Wilderness Living and Survival Skills",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781603580953"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1603580956"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 514,
#       "printType": "BOOK",
#       "categories": [
#         "Social Science"
#       ],
#       "averageRating": 3,
#       "ratingsCount": 2,
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "2.5.4.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=SKt_u35t9hsC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=SKt_u35t9hsC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=SKt_u35t9hsC&pg=PA55&dq=food&hl=&as_brr=6&cd=2&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=SKt_u35t9hsC&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=SKt_u35t9hsC"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 27.82,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 27.82,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=SKt_u35t9hsC&rdid=book-SKt_u35t9hsC&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 27820000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 27820000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/When_Technology_Fails-sample-epub.acsm?id=SKt_u35t9hsC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/When_Technology_Fails-sample-pdf.acsm?id=SKt_u35t9hsC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=SKt_u35t9hsC&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>foods</b>. I suggest using quality supplements manu- factured from live <b>foods</b> wherever possible (check your local health <b>food</b> store). \u2022 Fuels, lighting sources, camping gear. Camping gear can provide you with portable shelter and materials&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "RgU9u9oUSDQC",
#     "etag": "s/AcAVIbgd4",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/RgU9u9oUSDQC",
#     "volumeInfo": {
#       "title": "Advances in Deep-Fat Frying of Foods",
#       "authors": [
#         "Servet Gulum Sumnu",
#         "Serpil Sahin"
#       ],
#       "publisher": "CRC Press",
#       "publishedDate": "2008-12-17",
#       "description": "Battered fried foods consistently remain in high demand despite concerns about their health aspects, prompting food processors to develop new methods and alternative oils and batters in the name of healthy, tasty fried foods and high-performance, cost-effective frying oil. With contributions from an international panel of food technology authoritie",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781420055597"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1420055593"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 330,
#       "printType": "BOOK",
#       "categories": [
#         "Technology & Engineering"
#       ],
#       "averageRating": 5,
#       "ratingsCount": 1,
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "1.3.6.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=RgU9u9oUSDQC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=RgU9u9oUSDQC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=RgU9u9oUSDQC&pg=PA140&dq=food&hl=&as_brr=6&cd=3&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=RgU9u9oUSDQC&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=RgU9u9oUSDQC"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 274.3,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 216.28,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=RgU9u9oUSDQC&rdid=book-RgU9u9oUSDQC&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 274300000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 216280000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Advances_in_Deep_Fat_Frying_of_Foods-sample-epub.acsm?id=RgU9u9oUSDQC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Advances_in_Deep_Fat_Frying_of_Foods-sample-pdf.acsm?id=RgU9u9oUSDQC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=RgU9u9oUSDQC&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>Food</b> Engineering 43 : 147\u201354 . 2000b . Water loss and oil uptake as a function of frying time . Journal of <b>Food</b> Engi- neering 44 : 39\u201346 . Krokida , M.K. , V. Oreopoulou , Z.B. Maroulis , and D. Marinos - Kouris . 2001. Colour changes&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "CSHOBQAAQBAJ",
#     "etag": "jjz37aO/QS8",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/CSHOBQAAQBAJ",
#     "volumeInfo": {
#       "title": "Solid State Fermentation for Foods and Beverages",
#       "authors": [
#         "Jian Chen",
#         "Yang Zhu"
#       ],
#       "publisher": "CRC Press",
#       "publishedDate": "2013-11-23",
#       "description": "Although one of the oldest microbial technologies used in food processing, solid-state fermentation (SSF) had, until recently, fallen out of favor. However, based on a series of established mathematical models, new design concepts for SSF bioreactors and process control strategies have been proposed, allowing SSF technology to reach new levels. Sol",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781439844977"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1439844976"
#         }
#       ],
#       "readingModes": {
#         "text": false,
#         "image": true
#       },
#       "pageCount": 404,
#       "printType": "BOOK",
#       "categories": [
#         "Science"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "1.4.4.0.preview.1",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=CSHOBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=CSHOBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=CSHOBQAAQBAJ&pg=PA350&dq=food&hl=&as_brr=6&cd=4&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=CSHOBQAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=CSHOBQAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 90.72,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 69.41,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=CSHOBQAAQBAJ&rdid=book-CSHOBQAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 90720000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 69410000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": false
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Solid_State_Fermentation_for_Foods_and_B-sample-pdf.acsm?id=CSHOBQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=CSHOBQAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>food</b> shortage problem. With the adaptation of <b>food</b> fermentation, the indigenous self- help famine relief has been successfully achieved. Most fermented <b>foods</b> appear to have been developed to ensure the nutrition of the family in the dry&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "uvaiAgAAQBAJ",
#     "etag": "wXNF+6mzr54",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/uvaiAgAAQBAJ",
#     "volumeInfo": {
#       "title": "In-Pack Processed Foods",
#       "subtitle": "Improving Quality",
#       "authors": [
#         "P Richardson"
#       ],
#       "publisher": "Elsevier",
#       "publishedDate": "2008-06-13",
#       "description": "Recent developments have enabled the production of in-pack processed foods with improved sensory quality as well as new types of heat-preserved products packaged in innovative containers. This book reviews these advances in packaging formats and processing technologies and their application to produce higher quality, safer foods.Opening chapters cover innovative can designs and non-traditional packaging formats, such as retort pouches. The second part of the book reviews the developments in processing and process control technology required by newer types of packaging. Part three addresses the safety of in-pack processed foods, including concerns over pathogens and hazardous compounds in processed foods. The book concludes with chapters on novel methods to optimise the quality of particular types of in-pack processed foods such as fruit and vegetables, meat, poultry and fish products.In-pack processed foods: improving quality is a valuable reference for professionals involved in the manufacture of this important group of food products and those researching in this area. - Reviews advances in packaging formats and processing technologies - Covers innovative can designs and non-traditional packaging formats - Examines the safety of in-pack processed foods, including concerns over pathogens",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781845694692"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1845694694"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 428,
#       "printType": "BOOK",
#       "categories": [
#         "Technology & Engineering"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "0.4.3.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=uvaiAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=uvaiAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=uvaiAgAAQBAJ&pg=PA401&dq=food&hl=&as_brr=6&cd=5&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=uvaiAgAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=uvaiAgAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 226.82,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 158.77,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=uvaiAgAAQBAJ&rdid=book-uvaiAgAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 226820000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 158770000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/In_Pack_Processed_Foods-sample-epub.acsm?id=uvaiAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/In_Pack_Processed_Foods-sample-pdf.acsm?id=uvaiAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=uvaiAgAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>Food</b> Science, 45(6), pp. 1517\u20131521. Parry, D. A. 1970, Fish as <b>food</b>, in Proteins as Human <b>Foods</b>, R. A. Lawrie, ed., Butterworths, London, p. 365. Pedrosa-Menabrito, A. and Regenstein, J. M. 1990, Shelf-life Extension of Fresh Fish&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "NmI7EAAAQBAJ",
#     "etag": "dDVylFgwOJ0",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/NmI7EAAAQBAJ",
#     "volumeInfo": {
#       "title": "Current Advances for Development of Functional Foods Modulating Inflammation and Oxidative Stress",
#       "authors": [
#         "Blanca Hernandez-Ledesma",
#         "Cristina Martinez-Villaluenga"
#       ],
#       "publisher": "Academic Press",
#       "publishedDate": "2021-12-03",
#       "description": "Current Advances for Development of Functional Foods Modulating Inflammation and Oxidative Stress presents the nutritional and technological aspects related to the development of functional foods with anti-inflammatory and antioxidant effects. Specifically, analytical approaches for the characterization of anti-inflammatory and antioxidant properties of healthy foods and functional constituents, as well as technological strategies for the extraction of compounds and fractions from raw materials to produce anti-inflammatory and antioxidant ingredients are addressed. In addition, the molecular mechanisms by which foods and their components can modulate inflammation and their oxidative stress effects on disease prevention are explored. Finally, clinical research addressing nutritional needs in pathological subjects with inflammatory diseases are considered. - Covers methods of analysis and extraction of anti-inflammatory and antioxidant compounds - Offers an overview of the main anti-inflammatory and antioxidant compounds in foods - Provides a guide on the mechanisms of action and health benefits of anti-inflammatory and antioxidant dietary bioactives",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9780128225844"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "012822584X"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 676,
#       "printType": "BOOK",
#       "categories": [
#         "Technology & Engineering"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "1.5.5.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=NmI7EAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=NmI7EAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=NmI7EAAAQBAJ&pg=PA81&dq=food&hl=&as_brr=6&cd=6&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=NmI7EAAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=NmI7EAAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 184.62,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 129.23,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=NmI7EAAAQBAJ&rdid=book-NmI7EAAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 184620000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 129230000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Current_Advances_for_Development_of_Func-sample-epub.acsm?id=NmI7EAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Current_Advances_for_Development_of_Func-sample-pdf.acsm?id=NmI7EAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=NmI7EAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>foods</b>. Application of multiple emulsions to formulate the functional <b>food</b> products have been recognized for several years such as the development of low-fat imitation creams, fat reduced mayonnaise (Moussaoui et al., 2017), low-fat&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "MJTLBQAAQBAJ",
#     "etag": "7VpAQ3qaJdA",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/MJTLBQAAQBAJ",
#     "volumeInfo": {
#       "title": "Fermented Foods and Beverages of the World",
#       "authors": [
#         "Jyoti Prakash Tamang",
#         "Kasipathy Kailasapathy"
#       ],
#       "publisher": "CRC Press",
#       "publishedDate": "2010-07-01",
#       "description": "Did you know? It's estimated that fermentation practices have been around since as early as 6000 BC, when wine was first being made in Caucasus and Mesopotamia. Today, there are roughly 5000 varieties of fermented foods and beverages prepared and consumed worldwide, which accounts for between five and forty percent of daily meals. Fermented Foods a",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781420094961"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1420094963"
#         }
#       ],
#       "readingModes": {
#         "text": false,
#         "image": true
#       },
#       "pageCount": 462,
#       "printType": "BOOK",
#       "categories": [
#         "Technology & Engineering"
#       ],
#       "averageRating": 5,
#       "ratingsCount": 1,
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "0.3.3.0.preview.1",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=MJTLBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=MJTLBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=MJTLBQAAQBAJ&pg=PA81&dq=food&hl=&as_brr=6&cd=7&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=MJTLBQAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=MJTLBQAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 211,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 165.64,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=MJTLBQAAQBAJ&rdid=book-MJTLBQAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 211000000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 165640000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": false
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Fermented_Foods_and_Beverages_of_the_Wor-sample-pdf.acsm?id=MJTLBQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=MJTLBQAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>Food</b> Composition and Analysis 20 : 113\u2013118 . Silla Santos , M.H. 1996. Biogenic amines : Their importance in <b>foods</b> . International Journal of <b>Food</b> Microbiology 29 : 213\u2013231 . Silva , C.F. , L.R. Batista , L.M. Abreu , E.S. Dias , and&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "mRebEAAAQBAJ",
#     "etag": "RRZq6vBRpD8",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/mRebEAAAQBAJ",
#     "volumeInfo": {
#       "title": "Biopolymers in Nutraceuticals and Functional Foods",
#       "authors": [
#         "Sreerag Gopi",
#         "Preetha Balakrishnan",
#         "Matej Bra\u010di\u010d"
#       ],
#       "publisher": "Royal Society of Chemistry",
#       "publishedDate": "2022-11-04",
#       "description": "As a result of their unique physical properties, biological membrane mimetics such as biopolymers are used in a broad range of scientific and technological applications. This comprehensive book covers new applications of biopolymers in the research and development of industrial scale nutraceutical and functional food grade products. All the major food biopolymers are included, from plant, animal and marine sources. Coverage also includes biopolymer-based drug delivery mechanisms intended for biological applications such as bio-detection of pathogens, fluorescent biological labels, and drug and gene delivery. This is the first interdisciplinary book to address this area specifically and is essential reading for those who produce the functional biopolymer materials as well as those who seek to incorporate them into appropriate nutraceutical, food and drug delivery products.",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781839168055"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1839168056"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 495,
#       "printType": "BOOK",
#       "categories": [
#         "Technology & Engineering"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "1.2.3.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=mRebEAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=mRebEAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=mRebEAAAQBAJ&pg=PT334&dq=food&hl=&as_brr=6&cd=8&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=mRebEAAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=mRebEAAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 236.32,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 165.42,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=mRebEAAAQBAJ&rdid=book-mRebEAAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 236320000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 165420000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Biopolymers_in_Nutraceuticals_and_Functi-sample-epub.acsm?id=mRebEAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Biopolymers_in_Nutraceuticals_and_Functi-sample-pdf.acsm?id=mRebEAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=mRebEAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>Food</b> and Health, ed. B. Caballero, P. Finglas and F. Toldr\u00e1, Elsevier Inc., Amsterdam, 1st edn, 2015, pp. 294\u2013300. 11. D. Mudgil, S. Barak and B. S. Khatkar, Guar Gum: processing, properties and <b>food</b> applications - A Review, J. <b>Food</b> Sci&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "6iyIEQAAQBAJ",
#     "etag": "c2SCK6hv78I",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/6iyIEQAAQBAJ",
#     "volumeInfo": {
#       "title": "Fermentation Biotechnology for Functional Foods",
#       "authors": [
#         "Kalidas Shetty",
#         "Lena G\u00e1lvez Ranilla"
#       ],
#       "publisher": "CRC Press",
#       "publishedDate": "2025-10-31",
#       "description": "Fermentation-based processing advanced with global food systems as humanity started to organize the domestication of agriculture from plant and animal sources. These advances emerged across regions of the world from river valley civilizations in Asia (Mesopotamia, India and China) and Africa (Egypt) to Meso-American civilizations. As food crops and animal foods emerged from domestication to advancements in post-harvest processing stages, growth of invisible microbial systems led to modified foods that aligned with local palates of the communities. This in several cases became part of food systems, as it added a mode of preservation and improved the food quality that was preferred by each community. This is how the early genesis of fermented foods from grains, fruits and vegetables to animal meats and milk products became an integral part of early civilizations over 4000 years ago and has now carried over and further developed across many countries in every region of the world. The foundations of these food fermentations are now an integral part of modern food advances as preferred food substrates and the microbial interactions that drive the metabolic processes in defined food matrixes are being scientifically advanced. This book focuses on bringing together diverse emergences and advancements of fermented foods across different regions of the world and how the metabolic processes associated with fermentation in several cases add health-relevant functional qualities across different food matrixes. This book contains 26 chapters from the Americas, Africa, Europe and Asia, bringing together the fermentation processes of diverse food substrates and their microbial processing and in several cases providing health-targeted functional benefits. Key Features: Discusses the rationale and basis of fermented food systems from across 26 diverse regions of the world with examples from the Americas, Asia, Europe and Africa Presents historical plant and animal food substrates and the metabolic processes of their fermentation across traditions of a range of countries Covers traditional food fermentations across diverse food substrates that have potentially health-relevant functional benefits Reflects and presents the role of historical, cultural and traditional food concepts of a diverse range of countries with many novel examples and how they have influenced health-relevant functional benefits Discusses the relevance of metabolic concepts of fermented and functional foods in advancing healthy food concepts This book is important for food scientists, nutritionists and the health care sector, but beyond this, it is also relevant for a wider global audience interested in a holistic health approach from food systems where examples of fermentation experience can inform new natural processing strategies to improve food quality and health.",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781040410448"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1040410448"
#         }
#       ],
#       "readingModes": {
#         "text": false,
#         "image": true
#       },
#       "pageCount": 497,
#       "printType": "BOOK",
#       "categories": [
#         "Technology & Engineering"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "preview-1.0.0",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=6iyIEQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=6iyIEQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=6iyIEQAAQBAJ&pg=PA158&dq=food&hl=&as_brr=6&cd=9&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=6iyIEQAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=6iyIEQAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 247.92,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 195.18,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=6iyIEQAAQBAJ&rdid=book-6iyIEQAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 247920000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 195180000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": false
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Fermentation_Biotechnology_for_Functiona-sample-pdf.acsm?id=6iyIEQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=6iyIEQAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>Food</b> Sciences and Nutrition 61, no. 2: 125\u2013137. Hassan, Z. 1980. Pekasam\u2014A fermented fish product (in Peninsular Malaysia). In Seminar on Modernization of Malaysian Cottage <b>Food</b> Industries. Serdang: Universiti Pertanian Malaysia. Ho&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "NGI7EAAAQBAJ",
#     "etag": "uxO41tvhiNY",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/NGI7EAAAQBAJ",
#     "volumeInfo": {
#       "title": "Functional Foods and their Implications for Health Promotion",
#       "authors": [
#         "Ioannis Zabetakis",
#         "Ronan Lordan",
#         "Alexandros Tsoupras",
#         "Dipak Ramji"
#       ],
#       "publisher": "Academic Press",
#       "publishedDate": "2022-12-03",
#       "description": "Functional Foods and Their Implications for Health Promotion presents functional foods, from raw ingredients to the final product, providing a detailed explanation on how these foods work and an overview of their impact on health. The book presents the functions of food against disease and discusses how healthier foods can be produced. Broken into four parts, the book presents a deep dive into plant-derived functional foods, dairy foods, marine food and beverages. The book includes case studies, applications, literature reviews and coverage of recent developments.Intended for nutritionists, dieticians, food technologists, as well as students and researchers working in nutrition, dietetics, and food science, this book is sure to be a welcomed resource. - Uses flow diagrams to highlight the effects of processing on produced functional foods - Combines information on the production/formulation of the food with data on bioactivities and bioavailability - Presents whole foods and not food components while also focusing on functionality and availability",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9780128238127"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "0128238127"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 406,
#       "printType": "BOOK",
#       "categories": [
#         "Technology & Engineering"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "1.9.9.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=NGI7EAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=NGI7EAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=NGI7EAAAQBAJ&pg=PA285&dq=food&hl=&as_brr=6&cd=10&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=NGI7EAAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=NGI7EAAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 163.52,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 114.46,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=NGI7EAAAQBAJ&rdid=book-NGI7EAAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 163520000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 114460000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Functional_Foods_and_their_Implications-sample-epub.acsm?id=NGI7EAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Functional_Foods_and_their_Implications-sample-pdf.acsm?id=NGI7EAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=NGI7EAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>food</b> allergies that are triggered by shellfish products. A common process-related hazard in regard to shellfish allergies is considered to be the use of metabisulfite. Sulfites are <b>food</b> allergens and they are labeled as such in <b>food</b>&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "WXtzBgAAQBAJ",
#     "etag": "XZVzuBLykqQ",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/WXtzBgAAQBAJ",
#     "volumeInfo": {
#       "title": "Strange Foods",
#       "authors": [
#         "Jerry Hopkins"
#       ],
#       "publisher": "Tuttle Publishing",
#       "publishedDate": "1999-11-15",
#       "description": "This gastrological romp shares tales of gustatory tidbits from six continents. Weaving history and autobiography, author Jerry Hopkins regales with an array of startling facts about the world's eating habits. Strange Foods begins with rat tales from the Roman Empire and imperial China and continues on to stories form locales where rat remains a mouth-watering hors d'oeuvre or hearty entr\u00e9e today. There are at least 40 serving suggestions for crocodile alone! And there are more than 250 photographs from acclaimed photographer Michael Freeman, whose aim is true and who eats what he shoots. This is gonzo food writing that's sure to change your mind, if not your palate.",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781462916764"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1462916767"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 253,
#       "printType": "BOOK",
#       "categories": [
#         "Travel"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "1.6.7.0.preview.3",
#       "panelizationSummary": {
# ...
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781603586009"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1603586008"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 201,
#       "printType": "BOOK",
#       "categories": [
#         "Nature"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "0.5.5.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=ck9HBAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=ck9HBAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=ck9HBAAAQBAJ&pg=PT186&dq=food&hl=&as_brr=6&cd=37&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=ck9HBAAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=ck9HBAAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 14.36,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 14.36,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=ck9HBAAAQBAJ&rdid=book-ck9HBAAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 14360000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 14360000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/In_the_Company_of_Bears-sample-epub.acsm?id=ck9HBAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/In_the_Company_of_Bears-sample-pdf.acsm?id=ck9HBAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=ck9HBAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>food</b> shortages. Still, our forests, for a number of reasons, fail to meet the <b>food</b> requirements for all of the bears all of the time. Some of the reasons derive from how we manage the land. As forests are logged off, the second growth&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "nx1vBAAAQBAJ",
#     "etag": "OV3Esp6ufes",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/nx1vBAAAQBAJ",
#     "volumeInfo": {
#       "title": "Advertising to Children",
#       "subtitle": "New Directions, New Media",
#       "authors": [
#         "M. Blades",
#         "C. Oates",
#         "F. Blumberg",
#         "B. Gunter"
#       ],
#       "publisher": "Springer",
#       "publishedDate": "2014-08-29",
#       "description": "This important source for students, researchers, advertisers and parents reviews the debates and presents new research about advertising to children. Chapters cover food and alcohol advertising, the effects of product placement and new media advertising, and the role of parents and teachers in helping children to learn more about advertising.",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781137313256"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1137313250"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 264,
#       "printType": "BOOK",
#       "categories": [
#         "Psychology"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "1.7.5.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=nx1vBAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=nx1vBAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=nx1vBAAAQBAJ&pg=PA57&dq=food&hl=&as_brr=6&cd=38&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=nx1vBAAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=nx1vBAAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 94.94,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 63.29,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=nx1vBAAAQBAJ&rdid=book-nx1vBAAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 94940000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 63290000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Advertising_to_Children-sample-epub.acsm?id=nx1vBAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Advertising_to_Children-sample-pdf.acsm?id=nx1vBAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=nx1vBAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>food</b> adverts and brand recognition Effects on <b>food</b> preferences and choice Borzekowski and Robinson (2001) carried out a randomized, controlled trial in which they showed preschool children a videotape of a cartoon either with or without&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "wBmuAgAAQBAJ",
#     "etag": "V2MoLZtNg+A",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/wBmuAgAAQBAJ",
#     "volumeInfo": {
#       "title": "Environmentalism, Resistance and Solidarity",
#       "subtitle": "The Politics of Friends of the Earth International",
#       "authors": [
#         "B. Doherty",
#         "T. Doyle"
#       ],
#       "publisher": "Springer",
#       "publishedDate": "2013-10-16",
#       "description": "Drawing from a rich mix of survey data, interviews, and access to internal meetings, Brian Doherty and Timothy Doyle show how FoEI has developed a distinctive environmentalism, which allows for the differences in context between regions and across the North-South divide.",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9781137316714"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "1137316713"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 260,
#       "printType": "BOOK",
#       "categories": [
#         "Political Science"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "1.4.4.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=wBmuAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=wBmuAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=wBmuAgAAQBAJ&pg=PA157&dq=food&hl=&as_brr=6&cd=39&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=wBmuAgAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=wBmuAgAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 52.74,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 34.28,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=wBmuAgAAQBAJ&rdid=book-wBmuAgAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 52740000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 34280000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Environmentalism_Resistance_and_Solidari-sample-epub.acsm?id=wBmuAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Environmentalism_Resistance_and_Solidari-sample-pdf.acsm?id=wBmuAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=wBmuAgAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... <b>food</b> system and &#39;the need to refocus attention on the billion and a half men and women who produce the <b>food</b> we all eat&#39;.3 FoEI was one of the forum&#39;s organizers, with REDES/FoE Uruguay&#39;s Mart\u00edn Drago sitting on the International&nbsp;..."
#     }
#   },
#   {
#     "kind": "books#volume",
#     "id": "0pDGAAAAQBAJ",
#     "etag": "3Sfnc2ljEos",
#     "selfLink": "https://www.googleapis.com/books/v1/volumes/0pDGAAAAQBAJ",
#     "volumeInfo": {
#       "title": "Risk Regulation in the United States and European Union",
#       "subtitle": "Controlling Chaos",
#       "authors": [
#         "A. Luedtke",
#         "L. Svedin",
#         "Thad E. Hall"
#       ],
#       "publisher": "Springer",
#       "publishedDate": "2010-06-07",
#       "description": "Globalization and technology have altered public fears and changed expectations of how government should make people safer. This book analyzes how Europeans and Americans perceive and regulate risk. The authors show how public fears about risk are filtered through political systems to pressure governments to insure against risk.",
#       "industryIdentifiers": [
#         {
#           "type": "ISBN_13",
#           "identifier": "9780230109476"
#         },
#         {
#           "type": "ISBN_10",
#           "identifier": "0230109470"
#         }
#       ],
#       "readingModes": {
#         "text": true,
#         "image": true
#       },
#       "pageCount": 220,
#       "printType": "BOOK",
#       "categories": [
#         "Business & Economics"
#       ],
#       "maturityRating": "NOT_MATURE",
#       "allowAnonLogging": false,
#       "contentVersion": "4.7.5.0.preview.3",
#       "panelizationSummary": {
#         "containsEpubBubbles": false,
#         "containsImageBubbles": false
#       },
#       "imageLinks": {
#         "smallThumbnail": "http://books.google.com/books/content?id=0pDGAAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#         "thumbnail": "http://books.google.com/books/content?id=0pDGAAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#       },
#       "language": "en",
#       "previewLink": "http://books.google.fr/books?id=0pDGAAAAQBAJ&pg=PA104&dq=food&hl=&as_brr=6&cd=40&source=gbs_api",
#       "infoLink": "https://play.google.com/store/books/details?id=0pDGAAAAQBAJ&source=gbs_api",
#       "canonicalVolumeLink": "https://play.google.com/store/books/details?id=0pDGAAAAQBAJ"
#     },
#     "saleInfo": {
#       "country": "FR",
#       "saleability": "FOR_SALE",
#       "isEbook": true,
#       "listPrice": {
#         "amount": 52.74,
#         "currencyCode": "EUR"
#       },
#       "retailPrice": {
#         "amount": 34.28,
#         "currencyCode": "EUR"
#       },
#       "buyLink": "https://play.google.com/store/books/details?id=0pDGAAAAQBAJ&rdid=book-0pDGAAAAQBAJ&rdot=1&source=gbs_api",
#       "offers": [
#         {
#           "finskyOfferType": 1,
#           "listPrice": {
#             "amountInMicros": 52740000,
#             "currencyCode": "EUR"
#           },
#           "retailPrice": {
#             "amountInMicros": 34280000,
#             "currencyCode": "EUR"
#           },
#           "giftable": true
#         }
#       ]
#     },
#     "accessInfo": {
#       "country": "FR",
#       "viewability": "PARTIAL",
#       "embeddable": true,
#       "publicDomain": false,
#       "textToSpeechPermission": "ALLOWED",
#       "epub": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Risk_Regulation_in_the_United_States_and-sample-epub.acsm?id=0pDGAAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "pdf": {
#         "isAvailable": true,
#         "acsTokenLink": "http://books.google.fr/books/download/Risk_Regulation_in_the_United_States_and-sample-pdf.acsm?id=0pDGAAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#       },
#       "webReaderLink": "http://play.google.com/books/reader?id=0pDGAAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#       "accessViewStatus": "SAMPLE",
#       "quoteSharingAllowed": false
#     },
#     "searchInfo": {
#       "textSnippet": "... (<b>Food</b> Standards Agency 2008a). In 2006 the EU introduced its newest set of regulations pertaining to <b>food</b> production hygiene. This regulation package included Regulation (EC) 852/2004 on the hygiene of foodstuffs, Regulation (EC) 853&nbsp;..."
#     }
#   }
# ]

# %% [markdown]
# Accéder au premier élément de _data_books_ pour afficher les données du premier livre.
#
# --> [Lien ressource](https://w3schools.tech/fr/tutorial/python/python_access_list_items) : accéder aux éléments d'une liste python

# %%
# Afficher le premier livre
print(json.dumps(data_books[0], indent=2))
# Out:
# {
#   "kind": "books#volume",
#   "id": "O-t9BAAAQBAJ",
#   "etag": "D9+ivUDCftU",
#   "selfLink": "https://www.googleapis.com/books/v1/volumes/O-t9BAAAQBAJ",
#   "volumeInfo": {
#     "title": "Encyclopedia of Food and Health",
#     "publisher": "Academic Press",
#     "publishedDate": "2015-08-26",
#     "description": "Approx.3876 pages Approx.3876 pages",
#     "industryIdentifiers": [
#       {
#         "type": "ISBN_13",
#         "identifier": "9780123849533"
#       },
#       {
#         "type": "ISBN_10",
#         "identifier": "0123849535"
#       }
#     ],
#     "readingModes": {
#       "text": false,
#       "image": true
#     },
#     "pageCount": 2379,
#     "printType": "BOOK",
#     "categories": [
#       "Technology & Engineering"
#     ],
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "2.6.5.0.preview.1",
#     "panelizationSummary": {
#       "containsEpubBubbles": false,
#       "containsImageBubbles": false
#     },
#     "imageLinks": {
#       "smallThumbnail": "http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#       "thumbnail": "http://books.google.com/books/content?id=O-t9BAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.fr/books?id=O-t9BAAAQBAJ&pg=RA2-PA1&dq=food&hl=&as_brr=6&cd=1&source=gbs_api",
#     "infoLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&source=gbs_api",
#     "canonicalVolumeLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ"
#   },
#   "saleInfo": {
#     "country": "FR",
#     "saleability": "FOR_SALE",
#     "isEbook": true,
#     "listPrice": {
#       "amount": 3334,
#       "currencyCode": "EUR"
#     },
#     "retailPrice": {
#       "amount": 3334,
#       "currencyCode": "EUR"
#     },
#     "buyLink": "https://play.google.com/store/books/details?id=O-t9BAAAQBAJ&rdid=book-O-t9BAAAQBAJ&rdot=1&source=gbs_api",
#     "offers": [
#       {
#         "finskyOfferType": 1,
#         "listPrice": {
#           "amountInMicros": 3334000000,
#           "currencyCode": "EUR"
#         },
#         "retailPrice": {
#           "amountInMicros": 3334000000,
#           "currencyCode": "EUR"
#         },
#         "giftable": true
#       }
#     ]
#   },
#   "accessInfo": {
#     "country": "FR",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#       "isAvailable": false
#     },
#     "pdf": {
#       "isAvailable": true,
#       "acsTokenLink": "http://books.google.fr/books/download/Encyclopedia_of_Food_and_Health-sample-pdf.acsm?id=O-t9BAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=O-t9BAAAQBAJ&hl=&as_brr=6&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#   },
#   "searchInfo": {
#     "textSnippet": "... <b>food</b>. Importance. of. <b>Food</b>. Classification. and. Description. The preparation of reliable data on <b>food</b> requires precise iden- tification of <b>foods</b>. Even data of good quality can be a source of error if they are derived from <b>foods</b> that are&nbsp;..."
#   }
# }

# %%
with open("show_books.json", "w", encoding="utf-8") as f:
    json.dump(data_books_raw, f, indent=2, ensure_ascii=False)

# %% [markdown]
# Dans les données du premier livre, chercher où se trouve les informations suivantes (il peut s'agir de dictionnaires imbriqués) :
# - le titre,
# - le prix,
# - la note (_averageRating_)
#
# Afficher ces informations (cf la note ci-dessus pour accéder aux éléments d'un dictionnaire en python).

# %%
title_first_book = data_books[0]["volumeInfo"]["title"]
price_first_book = data_books[0]["saleInfo"]["listPrice"]["amount"]
average_rating_first_book = data_books[0]["volumeInfo"].get("averageRating", "nonexistante")
print(f"Titre : {title_first_book}")
print(f"Prix : {price_first_book}")
print(f"Note : {average_rating_first_book}")
# Out:
# Titre : Encyclopedia of Food and Health
# Prix : 3334
# Note : nonexistante

# %%
# Afficher les infos clés (price, title, rating) pour chaque livres de la liste data_books
for book in data_books:
        volume_info = book.get("volumeInfo", {})
        sale_info = book.get("saleInfo", {})

        title = volume_info.get("title")
        price = sale_info.get("listPrice", {}).get("amount")
        rating = volume_info.get("averegeRating")

        print(f"Titre : {title}")
        print(f"Prix : {price}")
        print(f"Note : {rating}")
        

#The {} here is just the default value in case the key is missing.
#book.get("volumeInfo", {}) → looks for the key "volumeInfo".
#If it exists → returns its dictionary.
#If it does not exist → returns {}
# Out:
# Titre : Encyclopedia of Food and Health
# Prix : 3334
# Note : None
# Titre : When Technology Fails
# Prix : 27.82
# Note : None
# Titre : Advances in Deep-Fat Frying of Foods
# Prix : 274.3
# Note : None
# Titre : Solid State Fermentation for Foods and Beverages
# Prix : 90.72
# Note : None
# Titre : In-Pack Processed Foods
# Prix : 226.82
# Note : None
# Titre : Current Advances for Development of Functional Foods Modulating Inflammation and Oxidative Stress
# Prix : 184.62
# Note : None
# Titre : Fermented Foods and Beverages of the World
# Prix : 211
# Note : None
# Titre : Biopolymers in Nutraceuticals and Functional Foods
# Prix : 236.32
# Note : None
# Titre : Fermentation Biotechnology for Functional Foods
# Prix : 247.92
# Note : None
# Titre : Functional Foods and their Implications for Health Promotion
# Prix : 163.52
# Note : None
# Titre : Strange Foods
# Prix : 10.99
# Note : None
# Titre : Olives and Olive Oil as Functional Foods
# Prix : 174.99
# Note : None
# Titre : Issues of Governance, Security, and Development in Contemporary Africa
# Prix : 118.34
# Note : None
# Titre : Food Waste to Valuable Resources
# Prix : 163.52
# Note : None
# Titre : Nutritional Coaching
# Prix : 12.99
# Note : None
# Titre : Cultivation for Climate Change Resilience, Volume 1
# Prix : 75.95
# Note : None
# Titre : Dojo: The Definitive Guide
# Prix : 26.9
# Note : None
# Titre : Encyclopedia of Food Grains
# Prix : 1968
# Note : None
# Titre : A Grammar of Emai
# Prix : 185.63
# Note : None
# Titre : Eco-Friendly Energy Processes and Technologies for Achieving Sustainable Development
# Prix : 184.21
# Note : None
# Titre : Allergy Essentials,E-Book
# Prix : 100.21
# Note : None
# Titre : Philosophy Comes to Dinner
# Prix : 54.85
# Note : None
# Titre : Nutraceuticals
# Prix : 242.65
# Note : None
# Titre : Interdisciplinary Behavior and Social Sciences
# Prix : 279.58
# Note : None
# Titre : Present Knowledge in Nutrition
# Prix : 138.2
# Note : None
# Titre : Encyclopedia of Spectroscopy and Spectrometry
# Prix : 2205
# Note : None
# Titre : The Human Side of Service Engineering
# Prix : 58.2
# Note : None
# Titre : The Rise of Food Charity in Europe
# Prix : 38.99
# Note : None
# Titre : International Development
# Prix : 58.45
# Note : None
# Titre : Food Science and Technology
# Prix : 121.27
# Note : None
# Titre : Ukrainian Cuisine with an American Touch and Ingredients
# Prix : 11.99
# Note : None
# Titre : Guinea
# Prix : 8.06
# Note : None
# Titre : Microbiologically Safe Foods
# Prix : 188.98
# Note : None
# Titre : A Guide to Federal Terms and Acronyms
# Prix : 203.6
# Note : None
# Titre : The Emergence of National Food
# Prix : 37.69
# Note : None
# Titre : On Evil
# Prix : 22.22
# Note : None
# Titre : In the Company of Bears
# Prix : 14.36
# Note : None
# Titre : Advertising to Children
# Prix : 94.94
# Note : None
# Titre : Environmentalism, Resistance and Solidarity
# Prix : 52.74
# Note : None
# Titre : Risk Regulation in the United States and European Union
# Prix : 52.74
# Note : None

# %% [markdown]
# Créer une liste de dictionnaire contenant les informations de chaque livre sous le format :
# ```
# [{
#     "title": "title0",
#     "price": price_0,
#     "rating": rating_0
# },
# {
#     "title": "title1",
#     "price": price_1,
#     "rating": rating_1
# },
# ...
# ]
# ```

# %%
# Création d'une liste de dictionnaires pour les livres
books_list = []

for book in data_books:
        volume_info = book.get("volumeInfo", {})
        sale_info = book.get("saleInfo", {})

        title = volume_info.get("title")
        price = sale_info.get("listPrice", {}).get("amount")
        rating = volume_info.get("averegeRating")

        book_dict = {
                "title" : title,
                "price" : price,
                "rating" : rating
        }

        books_list.append(book_dict)

# %%
# Créer un dataframe à partir de la liste de dictionnaires
df = pd.DataFrame(books_list)
print(df.head())
# Out:
#                                               title    price rating
# 0                   Encyclopedia of Food and Health  3334.00   None
# 1                             When Technology Fails    27.82   None
# 2              Advances in Deep-Fat Frying of Foods   274.30   None
# 3  Solid State Fermentation for Foods and Beverages    90.72   None
# 4                           In-Pack Processed Foods   226.82   None

# %% [markdown]
# Filtrer les livres pour ne conserver que ceux ayant des valeurs pour les colonnes _price_ et _rating_.
#
# - Possibilité d'utiliser la méthode pandas [_dropna_](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)
# - Afficher le dataframe et regarder ce qu'il s'est passé au niveau des index.
# - Utiliser la méthode [_reset_index_](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html) pour réinitialiser les index.

# %%
# Filter les livres pour ne conserver que ceux ayant des valeurs pour les colonnes price et rating
df = df.copy()
df_clean = df.dropna(subset=["price", "rating"])

# Reinitialiser les index du DataFrame
df_clean = df_clean.reset_index(drop=True)
print(df_clean.head())

# Ajouter une colonne availability = False
df_clean["availability"] = False
# Out:
# Empty DataFrame
# Columns: [title, price, rating]
# Index: []

# %% [markdown]
# ---
# ## Partie 3 : Insertion des données en base

# %%
# Utiliser sqlite3 pour insérer les données dans la base de données book_store dans la table book
import sqlite3

connection = sqlite3.connect("/home/emese/Briefs_test/scraping/book_store.db")
df_clean.to_sql('book_store', connection, if_exists='replace')
connection.commit()

# %%
# Vérifier que le nombre de livres dans la table correspond au nb de livres scrapés + livres de l'API
# Création d'un curseur pour interagir avec la DB
cursor = connection.cursor()

# Exécuter la requête pour compter le nombre de livre dans la DB
cursor.execute("SELECT COUNT(*) FROM book_store")

# Affichage du résultat
print(cursor.fetchone()[0])


connection.close()
# Out:
# 0
